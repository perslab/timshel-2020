# %%
import os
import sys

import numpy as np
import pandas as pd

# %%
# lib_path = os.path.abspath(os.path.pardir) # same as os.path.abspath("..")
lib_path = "/raid5/projects/timshel/sc-genetics/sc-genetics/src/lib"
sys.path.insert(1, lib_path)
from sem_pre_calculation import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Constants

# %% [markdown]
# ### Read data

# %%
### Metadata
file_metadata = "/scratch/data-for_fast_access/pub-others/campbell2017/campbell.cell_metadata.csv"
df_metadata = pd.read_csv(file_metadata, index_col=False)
df_metadata.head()
# Out:
#    nGene   nUMI orig.ident            cell_id treatment  diet  \
# 0   7876  50341       arc1  arc1_TACTAACAGTAN      arc1  Chow
# 1   6427  27357       arc1  arc1_CCGCGAGCTCTT      arc1  Chow
# 2   5684  26335       arc1  arc1_GTTGCACGGATA      arc1  Chow
# 3   5237  22311       arc1  arc1_CTGGCATTTTAT      arc1  Chow
# 4   5253  20902       arc1  arc1_TGCAACGACTAT      arc1  Chow
#
#   cell_type_all_lvl1 cell_type_all_lvl2                     age sex batch  \
# 0       a18.Neurons6  n34.unassigned(2)  adult (4-12 weeks old)   M    b1
# 1     a19.ParsTuber1   s10.Pars_Tuber1C  adult (4-12 weeks old)   M    b1
# 2       a13.Neurons1            n06.Oxt  adult (4-12 weeks old)   M    b1
# 3       a18.Neurons6    n13.Agrp/Gm8773  adult (4-12 weeks old)   M    b1
# 4       a18.Neurons6    n13.Agrp/Gm8773  adult (4-12 weeks old)   M    b1
#
#    FvF taxonomy_lvl1   taxonomy_lvl2
# 0  Fed        Neuron          Neuron
# 1  Fed     Endocrine  Pars tuberalis
# 2  Fed        Neuron          Neuron
# 3  Fed        Neuron          Neuron
# 4  Fed        Neuron          Neuron

# %%
### Data
file_data = "/scratch/data-for_fast_access/pub-others/campbell2017/campbell.umi.csv.gz"
df_data = pd.read_csv(file_data, index_col=False) # this takes 4 min for Campbell! (Pandas is slow!)

# %%
df_data.set_index("gene", inplace=True) # set index
df_data.head()
# Out:
#                arc1_TACTAACAGTAN  arc1_CCGCGAGCTCTT  arc1_GTTGCACGGATA  \
# gene
# 0610005C13Rik                  0                  0                  0
# 0610007P14Rik                  1                  0                  0
# 0610009B22Rik                  6                  5                  3
# 0610009E02Rik                  0                  0                  1
# 0610009L18Rik                  0                  2                  0
#
#                arc1_CTGGCATTTTAT  arc1_TGCAACGACTAT  arc1_CCGTAATACTTN  \
# gene
# 0610005C13Rik                  0                  0                  1
# 0610007P14Rik                  0                  0                  0
# 0610009B22Rik                  2                  1                  1
# 0610009E02Rik                  0                  0                  0
# 0610009L18Rik                  0                  0                  0
#
#                arc1_CAATCCGCTGGN  arc1_ACAAGTCATGAT  arc1_ACGAGCCCTCCA  \
# gene
# 0610005C13Rik                  0                  0                  0
# 0610007P14Rik                  1                  0                  1
# 0610009B22Rik                  0                  1                  2
# 0610009E02Rik                  0                  0                  0
# 0610009L18Rik                  0                  1                  0
#
#                arc1_GAATTAGGGGTC          ...           MaleFed_AGTGTAGGCGGN  \
# gene                                      ...
# 0610005C13Rik                  0          ...                              0
# 0610007P14Rik                  0          ...                              0
# 0610009B22Rik                  0          ...                              0
# 0610009E02Rik                  0          ...                              0
# 0610009L18Rik                  0          ...                              0
#
#                MaleFed_GAGACTAGTGCN  MaleFed_ACCACCGAGTCN  \
# gene
# 0610005C13Rik                     0                     0
# 0610007P14Rik                     0                     0
# 0610009B22Rik                     0                     1
# 0610009E02Rik                     0                     0
# 0610009L18Rik                     0                     0
#
#                MaleFed_AGGCAGCCCTTA  MaleFed_GGTAGTGTTGGN  \
# gene
# 0610005C13Rik                     0                     0
# 0610007P14Rik                     1                     0
# 0610009B22Rik                     0                     1
# 0610009E02Rik                     0                     0
# 0610009L18Rik                     0                     0
#
#                MaleFed_AAGCAGCGCAAC  MaleFed_CGACAATGTCGN  \
# gene
# 0610005C13Rik                     0                     0
# 0610007P14Rik                     0                     0
# 0610009B22Rik                     0                     0
# 0610009E02Rik                     0                     0
# 0610009L18Rik                     0                     0
#
#                MaleFed_GCGTTCAGCCTN  MaleFed_TGACGCGTTCTT  \
# gene
# 0610005C13Rik                     0                     0
# 0610007P14Rik                     0                     0
# 0610009B22Rik                     0                     0
# 0610009E02Rik                     0                     0
# 0610009L18Rik                     0                     0
#
#                MaleFed_GGGGCTTATTGN
# gene
# 0610005C13Rik                     0
# 0610007P14Rik                     0
# 0610009B22Rik                     1
# 0610009E02Rik                     0
# 0610009L18Rik                     0
#
# [5 rows x 20921 columns]

# %%
### [*IMPORTANT*] Check that all metadata cell_ids are identical to data columnnames. 
### We need to ensure this before we can use the metadata cell-types as annotations.
np.all(df_data.columns.values == df_metadata["cell_id"].values) # ---> True
# Out:
# True

# %% [markdown]
# ### CTC log normalize

# %%
df_ctc_log = ctc_log_normalize(df_data)
# Out:
# Performning common transcript count (ctc) normalization and log-transformation on input data

# %% [markdown]
# ### Run pre-calc for cell_type_all_lvl1 and cell_type_all_lvl2

# %%
dict_run = {"campbell_lvl1":"cell_type_all_lvl1",
            "campbell_lvl2":"cell_type_all_lvl2"}

# %%
for out_prefix in dict_run:
    annotations = df_metadata[dict_run[out_prefix]].values # get annotations
    print(annotations[:5])
    df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)
    df_anova.to_csv("{}.pre_calc.sporadically_expressed_genes.anova.csv.gz".format(out_prefix), compression="gzip")
    (df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)
    (df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)
# Out:
# ['a18.Neurons6' 'a19.ParsTuber1' 'a13.Neurons1' 'a18.Neurons6'
#  'a18.Neurons6']
# Splitting data frame into annotation groups
# Splitting annotation #1/#20 into group
# Splitting annotation #2/#20 into group
# Splitting annotation #3/#20 into group
# Splitting annotation #4/#20 into group
# Splitting annotation #5/#20 into group
# Splitting annotation #6/#20 into group
# Splitting annotation #7/#20 into group
# Splitting annotation #8/#20 into group
# Splitting annotation #9/#20 into group
# Splitting annotation #10/#20 into group
# Splitting annotation #11/#20 into group
# Splitting annotation #12/#20 into group
# Splitting annotation #13/#20 into group
# Splitting annotation #14/#20 into group
# Splitting annotation #15/#20 into group
# Splitting annotation #16/#20 into group
# Splitting annotation #17/#20 into group
# Splitting annotation #18/#20 into group
# Splitting annotation #19/#20 into group
# Splitting annotation #20/#20 into group
# Running ANOVA
# gene 0 out of 26774
# gene 100 out of 26774
# /tools/anaconda/3-4.4.0/envs/py3_anaconda3_PT180510/lib/python3.6/site-packages/scipy/stats/stats.py:2933: RuntimeWarning: invalid value encountered in double_scalars
#   f = msb / msw
# gene 200 out of 26774
# gene 300 out of 26774
# gene 400 out of 26774
# gene 500 out of 26774
# gene 600 out of 26774
# gene 700 out of 26774
# gene 800 out of 26774
# gene 900 out of 26774
# gene 1000 out of 26774
# gene 1100 out of 26774
# gene 1200 out of 26774
# gene 1300 out of 26774
# gene 1400 out of 26774
# gene 1500 out of 26774
# gene 1600 out of 26774
# gene 1700 out of 26774
# gene 1800 out of 26774
# gene 1900 out of 26774
# gene 2000 out of 26774
# gene 2100 out of 26774
# gene 2200 out of 26774
# gene 2300 out of 26774
# gene 2400 out of 26774
# gene 2500 out of 26774
# gene 2600 out of 26774
# gene 2700 out of 26774
# gene 2800 out of 26774
# gene 2900 out of 26774
# gene 3000 out of 26774
# gene 3100 out of 26774
# gene 3200 out of 26774
# gene 3300 out of 26774
# gene 3400 out of 26774
# gene 3500 out of 26774
# gene 3600 out of 26774
# gene 3700 out of 26774
# gene 3800 out of 26774
# gene 3900 out of 26774
# gene 4000 out of 26774
# gene 4100 out of 26774
# gene 4200 out of 26774
# gene 4300 out of 26774
# gene 4400 out of 26774
# gene 4500 out of 26774
# gene 4600 out of 26774
# gene 4700 out of 26774
# gene 4800 out of 26774
# gene 4900 out of 26774
# gene 5000 out of 26774
# gene 5100 out of 26774
# gene 5200 out of 26774
# gene 5300 out of 26774
# gene 5400 out of 26774
# gene 5500 out of 26774
# gene 5600 out of 26774
# gene 5700 out of 26774
# gene 5800 out of 26774
# gene 5900 out of 26774
# gene 6000 out of 26774
# gene 6100 out of 26774
# gene 6200 out of 26774
# gene 6300 out of 26774
# gene 6400 out of 26774
# gene 6500 out of 26774
# gene 6600 out of 26774
# gene 6700 out of 26774
# gene 6800 out of 26774
# gene 6900 out of 26774
# gene 7000 out of 26774
# gene 7100 out of 26774
# gene 7200 out of 26774
# gene 7300 out of 26774
# gene 7400 out of 26774
# gene 7500 out of 26774
# gene 7600 out of 26774
# gene 7700 out of 26774
# gene 7800 out of 26774
# gene 7900 out of 26774
# gene 8000 out of 26774
# gene 8100 out of 26774
# gene 8200 out of 26774
# gene 8300 out of 26774
# gene 8400 out of 26774
# gene 8500 out of 26774
# gene 8600 out of 26774
# gene 8700 out of 26774
# gene 8800 out of 26774
# gene 8900 out of 26774
# gene 9000 out of 26774
# gene 9100 out of 26774
# gene 9200 out of 26774
# gene 9300 out of 26774
# gene 9400 out of 26774
# gene 9500 out of 26774
# gene 21400 out of 26774
# gene 21500 out of 26774
# gene 21600 out of 26774
# gene 21700 out of 26774
# gene 21800 out of 26774
# gene 21900 out of 26774
# gene 22000 out of 26774
# gene 22100 out of 26774
# gene 22200 out of 26774
# gene 22300 out of 26774
# gene 22400 out of 26774
# gene 22500 out of 26774
# gene 22600 out of 26774
# gene 22700 out of 26774
# gene 22800 out of 26774
# gene 22900 out of 26774
# gene 23000 out of 26774
# gene 23100 out of 26774
# gene 23200 out of 26774
# gene 23300 out of 26774
# gene 23400 out of 26774
# gene 23500 out of 26774
# gene 23600 out of 26774
# gene 23700 out of 26774
# gene 23800 out of 26774
# gene 23900 out of 26774
# gene 24000 out of 26774
# gene 24100 out of 26774
# gene 24200 out of 26774
# gene 24300 out of 26774
# gene 24400 out of 26774
# gene 24500 out of 26774
# gene 24600 out of 26774
# gene 24700 out of 26774
# gene 24800 out of 26774
# gene 24900 out of 26774
# gene 25000 out of 26774
# gene 25100 out of 26774
# gene 25200 out of 26774
# gene 25300 out of 26774
# gene 25400 out of 26774
# gene 25500 out of 26774
# gene 25600 out of 26774
# gene 25700 out of 26774
# gene 25800 out of 26774
# gene 25900 out of 26774
# gene 26000 out of 26774
# gene 26100 out of 26774
# gene 26200 out of 26774
# gene 26300 out of 26774
# gene 26400 out of 26774
# gene 26500 out of 26774
# gene 26600 out of 26774
# gene 26700 out of 26774
# Number of genes sporadically expressed (pvalue > 0.00001, Skene cut-off): 10055
# Running: #1/#20 | a01.Oligodend3
# Running: #2/#20 | a02.Oligodend2
# Running: #3/#20 | a03.EndothelialCells
# Running: #4/#20 | a04.MuralCells
# Running: #5/#20 | a05.Oligodend1
# Running: #6/#20 | a06.NG2/OPC
# Running: #7/#20 | a07.PVMMicro
# Running: #8/#20 | a08.Fibroblast
# Running: #9/#20 | a09.Ependymocytes
# Running: #10/#20 | a10.Astrocyte
# Running: #11/#20 | a11.Tanycyte1
# Running: #12/#20 | a12.Tanycyte2
# Running: #13/#20 | a13.Neurons1
# Running: #14/#20 | a14.Neurons2
# Running: #15/#20 | a15.Neurons3
# Running: #16/#20 | a16.Neurons4
# Running: #17/#20 | a17.Neurons5
# Running: #18/#20 | a18.Neurons6
# Running: #19/#20 | a19.ParsTuber1
# Running: #20/#20 | a20.ParsTuber2
# Writing files...
# Doing null computation. Permuting labels with seed(1).
# Running: #1/#20 | a01.Oligodend3
# Running: #2/#20 | a02.Oligodend2
# Running: #3/#20 | a03.EndothelialCells
# Running: #4/#20 | a04.MuralCells
# Running: #5/#20 | a05.Oligodend1
# Running: #6/#20 | a06.NG2/OPC
# Running: #7/#20 | a07.PVMMicro
# Running: #8/#20 | a08.Fibroblast
# Running: #9/#20 | a09.Ependymocytes
# Running: #10/#20 | a10.Astrocyte
# Running: #11/#20 | a11.Tanycyte1
# Running: #12/#20 | a12.Tanycyte2
# Running: #13/#20 | a13.Neurons1
# Running: #14/#20 | a14.Neurons2
# Running: #15/#20 | a15.Neurons3
# Running: #16/#20 | a16.Neurons4
# Running: #17/#20 | a17.Neurons5
# Running: #18/#20 | a18.Neurons6
# Running: #19/#20 | a19.ParsTuber1
# Running: #20/#20 | a20.ParsTuber2
# Writing files...
# ['n34.unassigned(2)' 's10.Pars_Tuber1C' 'n06.Oxt' 'n13.Agrp/Gm8773'
#  'n13.Agrp/Gm8773']
# Splitting data frame into annotation groups
# Splitting annotation #1/#64 into group
# Splitting annotation #2/#64 into group
# Splitting annotation #3/#64 into group
# Splitting annotation #4/#64 into group
# Splitting annotation #5/#64 into group
# Splitting annotation #6/#64 into group
# Splitting annotation #7/#64 into group
# Splitting annotation #8/#64 into group
# Splitting annotation #9/#64 into group
# Splitting annotation #10/#64 into group
# Splitting annotation #11/#64 into group
# Splitting annotation #12/#64 into group
# Splitting annotation #13/#64 into group
# Splitting annotation #14/#64 into group
# Splitting annotation #15/#64 into group
# Splitting annotation #16/#64 into group
# Splitting annotation #17/#64 into group
# Splitting annotation #18/#64 into group
# Splitting annotation #19/#64 into group
# Splitting annotation #20/#64 into group
# Splitting annotation #21/#64 into group
# Splitting annotation #22/#64 into group
# Splitting annotation #23/#64 into group
# Splitting annotation #24/#64 into group
# Splitting annotation #25/#64 into group
# Splitting annotation #26/#64 into group
# Splitting annotation #27/#64 into group
# Splitting annotation #28/#64 into group
# Splitting annotation #29/#64 into group
# Splitting annotation #30/#64 into group
# Splitting annotation #31/#64 into group
# Splitting annotation #32/#64 into group
# Splitting annotation #33/#64 into group
# Splitting annotation #34/#64 into group
# Splitting annotation #35/#64 into group
# Splitting annotation #36/#64 into group
# Splitting annotation #37/#64 into group
# Splitting annotation #38/#64 into group
# Splitting annotation #39/#64 into group
# Splitting annotation #40/#64 into group
# Splitting annotation #41/#64 into group
# Splitting annotation #42/#64 into group
# Splitting annotation #43/#64 into group
# Splitting annotation #44/#64 into group
# Splitting annotation #45/#64 into group
# Splitting annotation #46/#64 into group
# Splitting annotation #47/#64 into group
# Splitting annotation #48/#64 into group
# Splitting annotation #49/#64 into group
# Splitting annotation #50/#64 into group
# Splitting annotation #51/#64 into group
# Splitting annotation #52/#64 into group
# Splitting annotation #53/#64 into group
# Splitting annotation #54/#64 into group
# Splitting annotation #55/#64 into group
# Splitting annotation #56/#64 into group
# Splitting annotation #57/#64 into group
# Splitting annotation #58/#64 into group
# Splitting annotation #59/#64 into group
# Splitting annotation #60/#64 into group
# Splitting annotation #61/#64 into group
# Splitting annotation #62/#64 into group
# Splitting annotation #63/#64 into group
# Splitting annotation #64/#64 into group
# Running ANOVA
# gene 0 out of 26774
# gene 100 out of 26774
# gene 200 out of 26774
# gene 300 out of 26774
# gene 400 out of 26774
# gene 500 out of 26774
# gene 600 out of 26774
# gene 700 out of 26774
# gene 800 out of 26774
# gene 900 out of 26774
# gene 1000 out of 26774
# gene 1100 out of 26774
# gene 1200 out of 26774
# gene 1300 out of 26774
# gene 1400 out of 26774
# gene 1500 out of 26774
# gene 1600 out of 26774
# gene 1700 out of 26774
# gene 1800 out of 26774
# gene 1900 out of 26774
# gene 2000 out of 26774
# gene 2100 out of 26774
# gene 25800 out of 26774
# gene 25900 out of 26774
# gene 26000 out of 26774
# gene 26100 out of 26774
# gene 26200 out of 26774
# gene 26300 out of 26774
# gene 26400 out of 26774
# gene 26500 out of 26774
# gene 26600 out of 26774
# gene 26700 out of 26774
# Number of genes sporadically expressed (pvalue > 0.00001, Skene cut-off): 10129
# Running: #1/#64 | n01.Hdc
# Running: #2/#64 | n02.Gm8773/Tac1
# Running: #3/#64 | n03
# Running: #4/#64 | n04.Sst/Nts
# Running: #5/#64 | n05.Nfix/Htr2c
# Running: #6/#64 | n06.Oxt
# Running: #7/#64 | n07
# Running: #8/#64 | n08
# Running: #9/#64 | n09.Th/Slc6a3
# Running: #10/#64 | n10.Ghrh
# Running: #11/#64 | n11.Th/Cxcl12
# Running: #12/#64 | n12.Agrp/Sst
# Running: #13/#64 | n13.Agrp/Gm8773
# Running: #14/#64 | n14.Pomc/Ttr
# Running: #15/#64 | n15.Pomc/Anxa2
# Running: #16/#64 | n16.Rgs16/Vip
# Running: #17/#64 | n17.Rgs16/Dlx1
# Running: #18/#64 | n18.Rgs16/Slc17a6
# Running: #19/#64 | n19.Gpr50
# Running: #20/#64 | n20.Kiss1/Tac2
# Running: #21/#64 | n21.Pomc/Glipr1
# Running: #22/#64 | n22.Tmem215
# Running: #23/#64 | n23.Sst/Unc13c
# Running: #24/#64 | n24.Sst/Pthlh
# Running: #25/#64 | n25.Th/Lef1
# Running: #26/#64 | n26.Htr3b
# Running: #27/#64 | n27
# Running: #28/#64 | n28.Qrfp
# Running: #29/#64 | n29.Nr5a1/Adcyap1
# Running: #30/#64 | n30.Nr5a1/Nfib
# Running: #31/#64 | n31.Fam19a2
# Running: #32/#64 | n32.Slc17a6/Trhr
# Running: #33/#64 | n33.unassigned(1)
# Running: #34/#64 | n34.unassigned(2)
# Running: #35/#64 | s01.Ependymocy1
# Running: #36/#64 | s02.Ependymocy2
# Running: #37/#64 | s03.Oligodendro1
# Running: #38/#64 | s04.Oligodendro2
# Running: #39/#64 | s05.Oligodendro3
# Running: #40/#64 | s06.Oligodendro4
# Running: #41/#64 | s07.Oligodendro5
# Running: #42/#64 | s08.Pars_Tuber1A
# Running: #43/#64 | s09.Pars_Tuber1B
# Running: #44/#64 | s10.Pars_Tuber1C
# Running: #45/#64 | s11.Endothelial
# Running: #46/#64 | s12.Mural_Cells1
# Running: #47/#64 | s13.Mural_Cells2
# Running: #48/#64 | s14.PVMs
# Running: #49/#64 | s15.Microglia
# Running: #50/#64 | s16.Fibroblasts1
# Running: #51/#64 | s17.Fibroblasts2
# Running: #52/#64 | s18.Fibroblasts3
# Running: #53/#64 | s19.Parstuber2A
# Running: #54/#64 | s20.Parstuber2B
# Running: #55/#64 | s27.Oligodendro6
# Running: #56/#64 | s28.NG2_OPC1
# Running: #57/#64 | s29.NG2_OPC2
# Running: #58/#64 | s30.b2_tanycytes1
# Running: #59/#64 | s31.b2_tanycytes2
# Running: #60/#64 | s32.Astrocytes
# Running: #61/#64 | s33.a1_tanycytes2
# Running: #62/#64 | s34.a1_tanycytes1
# Running: #63/#64 | s35.b1_tanycytes
# Running: #64/#64 | s36.a2_tanycytes
# Writing files...
# Doing null computation. Permuting labels with seed(1).
# Running: #1/#64 | n01.Hdc
# Running: #2/#64 | n02.Gm8773/Tac1
# Running: #3/#64 | n03
# Running: #4/#64 | n04.Sst/Nts
# Running: #5/#64 | n05.Nfix/Htr2c
# Running: #6/#64 | n06.Oxt
# Running: #7/#64 | n07
# Running: #8/#64 | n08
# Running: #9/#64 | n09.Th/Slc6a3
# Running: #10/#64 | n10.Ghrh
# Running: #11/#64 | n11.Th/Cxcl12
# Running: #12/#64 | n12.Agrp/Sst
# Running: #13/#64 | n13.Agrp/Gm8773
# Running: #14/#64 | n14.Pomc/Ttr
# Running: #15/#64 | n15.Pomc/Anxa2
# Running: #16/#64 | n16.Rgs16/Vip
# Running: #17/#64 | n17.Rgs16/Dlx1
# Running: #18/#64 | n18.Rgs16/Slc17a6
# Running: #19/#64 | n19.Gpr50
# Running: #20/#64 | n20.Kiss1/Tac2
# Running: #21/#64 | n21.Pomc/Glipr1
# Running: #22/#64 | n22.Tmem215
# Running: #23/#64 | n23.Sst/Unc13c
# Running: #24/#64 | n24.Sst/Pthlh
# Running: #25/#64 | n25.Th/Lef1
# Running: #26/#64 | n26.Htr3b
# Running: #27/#64 | n27
# Running: #28/#64 | n28.Qrfp
# Running: #29/#64 | n29.Nr5a1/Adcyap1
# Running: #30/#64 | n30.Nr5a1/Nfib
# Running: #31/#64 | n31.Fam19a2
# Running: #32/#64 | n32.Slc17a6/Trhr
# Running: #33/#64 | n33.unassigned(1)
# Running: #34/#64 | n34.unassigned(2)
# Running: #35/#64 | s01.Ependymocy1
# Running: #36/#64 | s02.Ependymocy2
# Running: #37/#64 | s03.Oligodendro1
# Running: #38/#64 | s04.Oligodendro2
# Running: #39/#64 | s05.Oligodendro3
# Running: #40/#64 | s06.Oligodendro4
# Running: #41/#64 | s07.Oligodendro5
# Running: #42/#64 | s08.Pars_Tuber1A
# Running: #43/#64 | s09.Pars_Tuber1B
# Running: #44/#64 | s10.Pars_Tuber1C
# Running: #45/#64 | s11.Endothelial
# Running: #46/#64 | s12.Mural_Cells1
# Running: #47/#64 | s13.Mural_Cells2
# Running: #48/#64 | s14.PVMs
# Running: #49/#64 | s15.Microglia
# Running: #50/#64 | s16.Fibroblasts1
# Running: #51/#64 | s17.Fibroblasts2
# Running: #52/#64 | s18.Fibroblasts3
# Running: #53/#64 | s19.Parstuber2A
# Running: #54/#64 | s20.Parstuber2B
# Running: #55/#64 | s27.Oligodendro6
# Running: #56/#64 | s28.NG2_OPC1
# Running: #57/#64 | s29.NG2_OPC2
# Running: #58/#64 | s30.b2_tanycytes1
# Running: #59/#64 | s31.b2_tanycytes2
# Running: #60/#64 | s32.Astrocytes
# Running: #61/#64 | s33.a1_tanycytes2
# Running: #62/#64 | s34.a1_tanycytes1
# Running: #63/#64 | s35.b1_tanycytes
# Running: #64/#64 | s36.a2_tanycytes
# Writing files...
