# %%
import os
import sys

import numpy as np
import pandas as pd

# %%
import git
path_repo_root = git.Repo('.', search_parent_directories=True).working_tree_dir

# %%
path_lib = os.path.join(path_repo_root, "src/lib")
sys.path.insert(1, path_lib)
from es_precalculation import *

# %% [markdown]
# # Constants

# %%
### Constants
input_dir = os.path.join(path_repo_root, "tmp-data/expression")
output_dir = os.path.join(path_repo_root, "tmp-data/expression-precalc")
assert(os.path.exists(output_dir)) # output_dir must exists

# %% [markdown]
# # Functions

# %%
def utils_celldata_reader(input_dir, prefix):
    """ Helper function to read .metadata.csv and .umi.csv.gz files in stored input_dir (tmp-data/expression)"""

    ### Metadata
    file_metadata = os.path.join(input_dir, "{}.metadata.csv".format(prefix))
    df_metadata = pd.read_csv(file_metadata, index_col=False)
    ### Data
    print("Reading UMI data...")
    file_data = os.path.join(input_dir, "{}.umi.csv.gz".format(prefix))
    df_data = pd.read_csv(file_data, index_col=False) # this takes 12-14 min for tabula_muris! (Pandas is slow!)
    print("Done reading UMI data")
    df_data.set_index("gene", inplace=True) # set index
    ### [*IMPORTANT*] Check that all metadata cell_ids are identical to data columnnames. 
    ### We need to ensure this before we can use the metadata cell-types as annotations.
    assert(np.all(df_data.columns.values == df_metadata["cell_id"].values)) # ---> True
    return [df_metadata, df_data]

# %% [markdown]
# # Mousebrain

# %%
import loompy # version 2

# %%
### Variables
out_prefix = os.path.join(output_dir, "mousebrain")
annotation_column = "ClusterName"

# %%
file_loom = os.path.join(input_dir, "mousebrain-l5_all.loom")
# file_loom = "/scratch/data-for_fast_access/pub-others/zeisel-biorxiv-2018/l5_all2.loom"
with loompy.connect(file_loom) as ds:
    ### Make data frame. Use Ensembl GeneIDs
    # ds.ra.Gene (Gene names) contains 66 duplicate gene names
    df_data = pd.DataFrame(ds[:, :].astype(int), index=ds.ra.Accession, columns=ds.ca.CellID)
    df_data.columns = pd.MultiIndex.from_arrays([ds.ca.CellID, ds.ca.ClusterName], names=["CellID", "ClusterName"])

# %%
df_ctc_log = ctc_log_normalize(df_data)
del df_data
# Out:
# Performning common transcript count (ctc) normalization and log-transformation on input data

# %%
annotations = df_ctc_log.columns.get_level_values(level=annotation_column) # 1 x NCell

# %%
df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)

# %%
(df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)

# %%
(df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)

# %% [markdown]
# # Tabula Muris

# %%
### Variables
out_prefix = os.path.join(output_dir, "tabula_muris")
annotation_column = "tissue_celltype"

# %%
[df_metadata, df_data] = utils_celldata_reader(input_dir, prefix="tabula_muris")
# Out:
# Reading UMI data...

# %%
df_ctc_log = ctc_log_normalize(df_data)
del df_data

# %%
### Set annotations
annotations = df_metadata[annotation_column].values

# %%
df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)

# %%
(df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)

# %%
(df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)

# %% [markdown]
# # Campbell2017

# %%
### Variables
dict_run = {os.path.join(output_dir, "campbell2017_lvl1"):"cell_type_all_lvl1",
            os.path.join(output_dir, "campbell2017_lvl2"):"cell_type_all_lvl2"} # {out_prefix:annotation_column}

# %%
[df_metadata, df_data] = utils_celldata_reader(input_dir, prefix="campbell2017")

# %%
df_ctc_log = ctc_log_normalize(df_data)
del df_data

# %%
for out_prefix in dict_run:
    print(out_prefix)
    annotations = df_metadata[dict_run[out_prefix]].values # get annotations
    df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)
    (df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)
    (df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)

# %% [markdown]
# # Chen2017

# %%
### Variables
dict_run = {os.path.join(output_dir, "chen2017"):"SVM_clusterID"} # {out_prefix:annotation_column}

# %%
[df_metadata, df_data] = utils_celldata_reader(input_dir, prefix="chen2017")
# Out:
# Reading UMI data...
# Done reading UMI data

# %%
df_ctc_log = ctc_log_normalize(df_data)
del df_data
# Out:
# Performning common transcript count (ctc) normalization and log-transformation on input data

# %%
for out_prefix in dict_run:
    print(out_prefix)
    annotations = df_metadata[dict_run[out_prefix]].values # get annotations
    df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)
    (df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)
    (df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)
# Out:
# /nfsdata/projects/jonatan/pub-perslab/timshel-bmicelltypes2019/tmp-data/expression-precalc/chen2017
# Splitting data frame into annotation groups
# Splitting annotation #1/#45 into group
# Splitting annotation #2/#45 into group
# Splitting annotation #3/#45 into group
# Splitting annotation #4/#45 into group
# Splitting annotation #5/#45 into group
# Splitting annotation #6/#45 into group
# Splitting annotation #7/#45 into group
# Splitting annotation #8/#45 into group
# Splitting annotation #9/#45 into group
# Splitting annotation #10/#45 into group
# Splitting annotation #11/#45 into group
# Splitting annotation #12/#45 into group
# Splitting annotation #13/#45 into group
# Splitting annotation #14/#45 into group
# Splitting annotation #15/#45 into group
# Splitting annotation #16/#45 into group
# Splitting annotation #17/#45 into group
# Splitting annotation #18/#45 into group
# Splitting annotation #19/#45 into group
# Splitting annotation #20/#45 into group
# Splitting annotation #21/#45 into group
# Splitting annotation #22/#45 into group
# Splitting annotation #23/#45 into group
# Splitting annotation #24/#45 into group
# Splitting annotation #25/#45 into group
# Splitting annotation #26/#45 into group
# Splitting annotation #27/#45 into group
# Splitting annotation #28/#45 into group
# Splitting annotation #29/#45 into group
# Splitting annotation #30/#45 into group
# Splitting annotation #31/#45 into group
# Splitting annotation #32/#45 into group
# Splitting annotation #33/#45 into group
# Splitting annotation #34/#45 into group
# Splitting annotation #35/#45 into group
# Splitting annotation #36/#45 into group
# Splitting annotation #37/#45 into group
# Splitting annotation #38/#45 into group
# Splitting annotation #39/#45 into group
# Splitting annotation #40/#45 into group
# Splitting annotation #41/#45 into group
# Splitting annotation #42/#45 into group
# Splitting annotation #43/#45 into group
# Splitting annotation #44/#45 into group
# Splitting annotation #45/#45 into group
# Running ANOVA
# gene 0 out of 23284
# /tools/anaconda/latest/lib/python3.7/site-packages/scipy/stats/stats.py:3235: RuntimeWarning: invalid value encountered in double_scalars
#   f = msb / msw
# gene 100 out of 23284
# gene 200 out of 23284
# gene 300 out of 23284
# gene 400 out of 23284
# gene 500 out of 23284
# gene 600 out of 23284
# gene 700 out of 23284
# gene 800 out of 23284
# gene 900 out of 23284
# gene 1000 out of 23284
# gene 1100 out of 23284
# gene 1200 out of 23284
# gene 1300 out of 23284
# gene 1400 out of 23284
# gene 1500 out of 23284
# gene 1600 out of 23284
# gene 1700 out of 23284
# gene 1800 out of 23284
# gene 1900 out of 23284
# gene 2000 out of 23284
# gene 2100 out of 23284
# gene 2200 out of 23284
# gene 2300 out of 23284
# gene 2400 out of 23284
# gene 2500 out of 23284
# gene 2600 out of 23284
# gene 2700 out of 23284
# gene 2800 out of 23284
# gene 2900 out of 23284
# gene 3000 out of 23284
# gene 3100 out of 23284
# gene 3200 out of 23284
# gene 3300 out of 23284
# gene 3400 out of 23284
# gene 3500 out of 23284
# gene 3600 out of 23284
# gene 3700 out of 23284
# gene 3800 out of 23284
# gene 3900 out of 23284
# gene 4000 out of 23284
# gene 4100 out of 23284
# gene 4200 out of 23284
# gene 4300 out of 23284
# gene 4400 out of 23284
# gene 4500 out of 23284
# gene 4600 out of 23284
# gene 4700 out of 23284
# gene 4800 out of 23284
# gene 4900 out of 23284
# gene 5000 out of 23284
# gene 5100 out of 23284
# gene 5200 out of 23284
# gene 5300 out of 23284
# gene 5400 out of 23284
# gene 5500 out of 23284
# gene 5600 out of 23284
# gene 5700 out of 23284
# gene 5800 out of 23284
# gene 5900 out of 23284
# gene 6000 out of 23284
# gene 6100 out of 23284
# gene 6200 out of 23284
# gene 6300 out of 23284
# gene 6400 out of 23284
# gene 6500 out of 23284
# gene 6600 out of 23284
# gene 6700 out of 23284
# gene 6800 out of 23284
# gene 6900 out of 23284
# gene 7000 out of 23284
# gene 7100 out of 23284
# gene 7200 out of 23284
# gene 7300 out of 23284
# gene 7400 out of 23284
# gene 7500 out of 23284
# gene 7600 out of 23284
# gene 7700 out of 23284
# gene 7800 out of 23284
# gene 7900 out of 23284
# gene 8000 out of 23284
# gene 8100 out of 23284
# gene 8200 out of 23284
# gene 8300 out of 23284
# gene 8400 out of 23284
# gene 8500 out of 23284
# gene 8600 out of 23284
# gene 8700 out of 23284
# gene 8800 out of 23284
# gene 8900 out of 23284
# gene 9000 out of 23284
# gene 9100 out of 23284
# gene 9200 out of 23284
# gene 9300 out of 23284
# gene 9400 out of 23284
# gene 9500 out of 23284
# gene 9600 out of 23284
# gene 9700 out of 23284
# gene 9800 out of 23284
# gene 9900 out of 23284
# gene 10000 out of 23284
# gene 10100 out of 23284
# gene 10200 out of 23284
# gene 10300 out of 23284
# gene 10400 out of 23284
# gene 10500 out of 23284
# gene 10600 out of 23284
# gene 10700 out of 23284
# gene 10800 out of 23284
# gene 10900 out of 23284
# gene 11000 out of 23284
# gene 11100 out of 23284
# gene 11200 out of 23284
# gene 11300 out of 23284
# gene 11400 out of 23284
# gene 11500 out of 23284
# gene 11600 out of 23284
# gene 11700 out of 23284
# gene 11800 out of 23284
# gene 11900 out of 23284
# gene 12000 out of 23284
# gene 12100 out of 23284
# gene 12200 out of 23284
# gene 12300 out of 23284
# gene 12400 out of 23284
# gene 12500 out of 23284
# gene 12600 out of 23284
# gene 12700 out of 23284
# gene 12800 out of 23284
# gene 12900 out of 23284
# gene 13000 out of 23284
# gene 13100 out of 23284
# gene 13200 out of 23284
# gene 13300 out of 23284
# gene 13400 out of 23284
# gene 13500 out of 23284
# gene 13600 out of 23284
# gene 13700 out of 23284
# gene 13800 out of 23284
# gene 13900 out of 23284
# gene 14000 out of 23284
# gene 14100 out of 23284
# gene 14200 out of 23284
# gene 14300 out of 23284
# gene 14400 out of 23284
# gene 14500 out of 23284
# gene 14600 out of 23284
# gene 14700 out of 23284
# gene 14800 out of 23284
# gene 14900 out of 23284
# gene 15000 out of 23284
# gene 15100 out of 23284
# gene 15200 out of 23284
# gene 15300 out of 23284
# gene 15400 out of 23284
# gene 15500 out of 23284
# gene 15600 out of 23284
# gene 15700 out of 23284
# gene 15800 out of 23284
# gene 15900 out of 23284
# gene 16000 out of 23284
# gene 16100 out of 23284
# gene 16200 out of 23284
# gene 16300 out of 23284
# gene 16400 out of 23284
# gene 16500 out of 23284
# gene 16600 out of 23284
# gene 16700 out of 23284
# gene 16800 out of 23284
# gene 16900 out of 23284
# gene 17000 out of 23284
# gene 17100 out of 23284
# gene 17200 out of 23284
# gene 17300 out of 23284
# gene 17400 out of 23284
# gene 17500 out of 23284
# gene 17600 out of 23284
# gene 17700 out of 23284
# gene 17800 out of 23284
# gene 17900 out of 23284
# gene 18000 out of 23284
# gene 18100 out of 23284
# gene 18200 out of 23284
# gene 18300 out of 23284
# gene 18400 out of 23284
# gene 18500 out of 23284
# gene 18600 out of 23284
# gene 18700 out of 23284
# gene 18800 out of 23284
# gene 18900 out of 23284
# gene 19000 out of 23284
# gene 19100 out of 23284
# gene 19200 out of 23284
# gene 19300 out of 23284
# gene 19400 out of 23284
# gene 19500 out of 23284
# gene 19600 out of 23284
# gene 19700 out of 23284
# gene 19800 out of 23284
# gene 19900 out of 23284
# gene 20000 out of 23284
# gene 20100 out of 23284
# gene 20200 out of 23284
# gene 20300 out of 23284
# gene 20400 out of 23284
# gene 20500 out of 23284
# gene 20600 out of 23284
# gene 20700 out of 23284
# gene 20800 out of 23284
# gene 20900 out of 23284
# gene 21000 out of 23284
# gene 21100 out of 23284
# gene 21200 out of 23284
# gene 21300 out of 23284
# gene 21400 out of 23284
# gene 21500 out of 23284
# gene 21600 out of 23284
# gene 21700 out of 23284
# gene 21800 out of 23284
# gene 21900 out of 23284
# gene 22000 out of 23284
# gene 22100 out of 23284
# gene 22200 out of 23284
# gene 22300 out of 23284
# gene 22400 out of 23284
# gene 22500 out of 23284
# gene 22600 out of 23284
# gene 22700 out of 23284
# gene 22800 out of 23284
# gene 22900 out of 23284
# gene 23000 out of 23284
# gene 23100 out of 23284
# gene 23200 out of 23284
# Writing out file...
# Number of genes sporadically expressed (pvalue > 0.00001): 8199
# Running: #1/#45 | Astro
# Running: #2/#45 | Ependy
# Running: #3/#45 | Epith1
# Running: #4/#45 | Epith2
# Running: #5/#45 | GABA1
# Running: #6/#45 | GABA10
# Running: #7/#45 | GABA11
# Running: #8/#45 | GABA12
# Running: #9/#45 | GABA13
# Running: #10/#45 | GABA14
# Running: #11/#45 | GABA15
# Running: #12/#45 | GABA16
# Running: #13/#45 | GABA17
# Running: #14/#45 | GABA18
# Running: #15/#45 | GABA2
# Running: #16/#45 | GABA3
# Running: #17/#45 | GABA4
# Running: #18/#45 | GABA5
# Running: #19/#45 | GABA6
# Running: #20/#45 | GABA7
# Running: #21/#45 | GABA8
# Running: #22/#45 | GABA9
# Running: #23/#45 | Glu1
# Running: #24/#45 | Glu10
# Running: #25/#45 | Glu11
# Running: #26/#45 | Glu12
# Running: #27/#45 | Glu13
# Running: #28/#45 | Glu14
# Running: #29/#45 | Glu15
# Running: #30/#45 | Glu2
# Running: #31/#45 | Glu3
# Running: #32/#45 | Glu4
# Running: #33/#45 | Glu5
# Running: #34/#45 | Glu6
# Running: #35/#45 | Glu7
# Running: #36/#45 | Glu8
# Running: #37/#45 | Glu9
# Running: #38/#45 | Hista
# Running: #39/#45 | IMO
# Running: #40/#45 | MO
# Running: #41/#45 | Macro
# Running: #42/#45 | Micro
# Running: #43/#45 | OPC
# Running: #44/#45 | POPC
# Running: #45/#45 | Tany
# Writing files...
# Doing null computation. Permuting labels with seed(1).
# Running: #1/#45 | Astro
# Running: #2/#45 | Ependy
# Running: #3/#45 | Epith1
# Running: #4/#45 | Epith2
# Running: #5/#45 | GABA1
# Running: #6/#45 | GABA10
# Running: #7/#45 | GABA11
# Running: #8/#45 | GABA12
# Running: #9/#45 | GABA13
# Running: #10/#45 | GABA14
# Running: #11/#45 | GABA15
# Running: #12/#45 | GABA16
# Running: #13/#45 | GABA17
# Running: #14/#45 | GABA18
# Running: #15/#45 | GABA2
# Running: #16/#45 | GABA3
# Running: #17/#45 | GABA4
# Running: #18/#45 | GABA5
# Running: #19/#45 | GABA6
# Running: #20/#45 | GABA7
# Running: #21/#45 | GABA8
# Running: #22/#45 | GABA9
# Running: #23/#45 | Glu1
# Running: #24/#45 | Glu10
# Running: #25/#45 | Glu11
# Running: #26/#45 | Glu12
# Running: #27/#45 | Glu13
# Running: #28/#45 | Glu14
# Running: #29/#45 | Glu15
# Running: #30/#45 | Glu2
# Running: #31/#45 | Glu3
# Running: #32/#45 | Glu4
# Running: #33/#45 | Glu5
# Running: #34/#45 | Glu6
# Running: #35/#45 | Glu7
# Running: #36/#45 | Glu8
# Running: #37/#45 | Glu9
# Running: #38/#45 | Hista
# Running: #39/#45 | IMO
# Running: #40/#45 | MO
# Running: #41/#45 | Macro
# Running: #42/#45 | Micro
# Running: #43/#45 | OPC
# Running: #44/#45 | POPC
# Running: #45/#45 | Tany
# Writing files...

# %% [markdown]
# # Romanov2017

# %%
### Variables
dict_run = {os.path.join(output_dir, "romanov2017"):"cell_type"} # {out_prefix:annotation_column}

# %%
[df_metadata, df_data] = utils_celldata_reader(input_dir, prefix="romanov2017")
# Out:
# Reading UMI data...
# Done reading UMI data

# %%
df_ctc_log = ctc_log_normalize(df_data)
del df_data
# Out:
# Performning common transcript count (ctc) normalization and log-transformation on input data

# %%
for out_prefix in dict_run:
    print(out_prefix)
    annotations = df_metadata[dict_run[out_prefix]].values # get annotations
    df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)
    (df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)
    (df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)
# Out:
# /nfsdata/projects/jonatan/pub-perslab/timshel-bmicelltypes2019/tmp-data/expression-precalc/romanov2017
# Splitting data frame into annotation groups
# Splitting annotation #1/#60 into group
# Splitting annotation #2/#60 into group
# Splitting annotation #3/#60 into group
# Splitting annotation #4/#60 into group
# Splitting annotation #5/#60 into group
# Splitting annotation #6/#60 into group
# Splitting annotation #7/#60 into group
# Splitting annotation #8/#60 into group
# Splitting annotation #9/#60 into group
# Splitting annotation #10/#60 into group
# Splitting annotation #11/#60 into group
# Splitting annotation #12/#60 into group
# Splitting annotation #13/#60 into group
# Splitting annotation #14/#60 into group
# Splitting annotation #15/#60 into group
# Splitting annotation #16/#60 into group
# Splitting annotation #17/#60 into group
# Splitting annotation #18/#60 into group
# Splitting annotation #19/#60 into group
# Splitting annotation #20/#60 into group
# Splitting annotation #21/#60 into group
# Splitting annotation #22/#60 into group
# Splitting annotation #23/#60 into group
# Splitting annotation #24/#60 into group
# Splitting annotation #25/#60 into group
# Splitting annotation #26/#60 into group
# Splitting annotation #27/#60 into group
# Splitting annotation #28/#60 into group
# Splitting annotation #29/#60 into group
# Splitting annotation #30/#60 into group
# Splitting annotation #31/#60 into group
# Splitting annotation #32/#60 into group
# Splitting annotation #33/#60 into group
# Splitting annotation #34/#60 into group
# Splitting annotation #35/#60 into group
# Splitting annotation #36/#60 into group
# Splitting annotation #37/#60 into group
# Splitting annotation #38/#60 into group
# Splitting annotation #39/#60 into group
# Splitting annotation #40/#60 into group
# Splitting annotation #41/#60 into group
# Splitting annotation #42/#60 into group
# Splitting annotation #43/#60 into group
# Splitting annotation #44/#60 into group
# Splitting annotation #45/#60 into group
# Splitting annotation #46/#60 into group
# Splitting annotation #47/#60 into group
# Splitting annotation #48/#60 into group
# Splitting annotation #49/#60 into group
# Splitting annotation #50/#60 into group
# Splitting annotation #51/#60 into group
# Splitting annotation #52/#60 into group
# Splitting annotation #53/#60 into group
# Splitting annotation #54/#60 into group
# Splitting annotation #55/#60 into group
# Splitting annotation #56/#60 into group
# Splitting annotation #57/#60 into group
# Splitting annotation #58/#60 into group
# Splitting annotation #59/#60 into group
# Splitting annotation #60/#60 into group
# Running ANOVA
# gene 0 out of 12884
# gene 100 out of 12884
# gene 200 out of 12884
# gene 300 out of 12884
# gene 400 out of 12884
# gene 500 out of 12884
# gene 600 out of 12884
# gene 700 out of 12884
# gene 800 out of 12884
# gene 900 out of 12884
# gene 1000 out of 12884
# gene 1100 out of 12884
# gene 1200 out of 12884
# gene 1300 out of 12884
# gene 1400 out of 12884
# gene 1500 out of 12884
# gene 1600 out of 12884
# gene 1700 out of 12884
# gene 1800 out of 12884
# gene 1900 out of 12884
# gene 2000 out of 12884
# gene 2100 out of 12884
# gene 2200 out of 12884
# gene 2300 out of 12884
# gene 2400 out of 12884
# gene 2500 out of 12884
# gene 2600 out of 12884
# gene 2700 out of 12884
# gene 2800 out of 12884
# gene 2900 out of 12884
# gene 3000 out of 12884
# gene 3100 out of 12884
# gene 3200 out of 12884
# gene 3300 out of 12884
# gene 3400 out of 12884
# gene 3500 out of 12884
# gene 3600 out of 12884
# gene 3700 out of 12884
# gene 3800 out of 12884
# gene 3900 out of 12884
# gene 4000 out of 12884
# gene 4100 out of 12884
# gene 4200 out of 12884
# gene 4300 out of 12884
# gene 4400 out of 12884
# gene 4500 out of 12884
# gene 4600 out of 12884
# gene 4700 out of 12884
# gene 4800 out of 12884
# gene 4900 out of 12884
# gene 5000 out of 12884
# gene 5100 out of 12884
# gene 5200 out of 12884
# gene 5300 out of 12884
# gene 5400 out of 12884
# gene 5500 out of 12884
# gene 5600 out of 12884
# gene 5700 out of 12884
# gene 5800 out of 12884
# gene 5900 out of 12884
# gene 6000 out of 12884
# gene 6100 out of 12884
# gene 6200 out of 12884
# gene 6300 out of 12884
# gene 6400 out of 12884
# gene 6500 out of 12884
# gene 6600 out of 12884
# gene 6700 out of 12884
# gene 6800 out of 12884
# gene 6900 out of 12884
# gene 7000 out of 12884
# gene 7100 out of 12884
# gene 7200 out of 12884
# gene 7300 out of 12884
# gene 7400 out of 12884
# gene 7500 out of 12884
# gene 7600 out of 12884
# gene 7700 out of 12884
# gene 7800 out of 12884
# gene 7900 out of 12884
# gene 8000 out of 12884
# gene 8100 out of 12884
# gene 8200 out of 12884
# gene 8300 out of 12884
# gene 8400 out of 12884
# gene 8500 out of 12884
# gene 8600 out of 12884
# gene 8700 out of 12884
# gene 8800 out of 12884
# gene 8900 out of 12884
# gene 9000 out of 12884
# gene 9100 out of 12884
# gene 9200 out of 12884
# gene 9300 out of 12884
# gene 9400 out of 12884
# gene 9500 out of 12884
# gene 9600 out of 12884
# gene 9700 out of 12884
# gene 9800 out of 12884
# gene 9900 out of 12884
# gene 10000 out of 12884
# gene 10100 out of 12884
# gene 10200 out of 12884
# gene 10300 out of 12884
# gene 10400 out of 12884
# gene 10500 out of 12884
# gene 10600 out of 12884
# gene 10700 out of 12884
# gene 10800 out of 12884
# gene 10900 out of 12884
# gene 11000 out of 12884
# gene 11100 out of 12884
# gene 11200 out of 12884
# gene 11300 out of 12884
# gene 11400 out of 12884
# gene 11500 out of 12884
# gene 11600 out of 12884
# gene 11700 out of 12884
# gene 11800 out of 12884
# gene 11900 out of 12884
# gene 12000 out of 12884
# gene 12100 out of 12884
# gene 12200 out of 12884
# gene 12300 out of 12884
# gene 12400 out of 12884
# gene 12500 out of 12884
# gene 12600 out of 12884
# gene 12700 out of 12884
# gene 12800 out of 12884
# Writing out file...
# Number of genes sporadically expressed (pvalue > 0.00001): 5324
# Running: #1/#60 | 1
# Running: #2/#60 | 2
# Running: #3/#60 | 3
# Running: #4/#60 | 4
# Running: #5/#60 | 6
# Running: #6/#60 | 7
# Running: #7/#60 | Adcyap1_1_Tac1
# Running: #8/#60 | Adcyap1_2
# Running: #9/#60 | Avp_1_high
# Running: #10/#60 | Avp_2_high
# Running: #11/#60 | Avp_3_medium
# Running: #12/#60 | Dopamine_1
# Running: #13/#60 | Dopamine_2_low_VMAT2
# Running: #14/#60 | Dopamine_3
# Running: #15/#60 | Dopamine_4
# Running: #16/#60 | GABA1
# Running: #17/#60 | GABA_10
# Running: #18/#60 | GABA_11_Nts_1
# Running: #19/#60 | GABA_12_Nts_2
# Running: #20/#60 | GABA_13_Galanin
# Running: #21/#60 | GABA_14_Npy_Agrp
# Running: #22/#60 | GABA_15_Npynegmedium
# Running: #23/#60 | GABA_2_Gucy1a3
# Running: #24/#60 | GABA_3_Crhpos_neg_Lhx6
# Running: #25/#60 | GABA_4_Crhpos_neg_Pgr15l
# Running: #26/#60 | GABA_5_Calcr_Lhx1
# Running: #27/#60 | GABA_6_Otof_Lhx1
# Running: #28/#60 | GABA_7_Pomcpos_neg
# Running: #29/#60 | GABA_8
# Running: #30/#60 | GABA_9
# Running: #31/#60 | Gadneglow_Gnrhneg_pos
# Running: #32/#60 | Hcrt
# Running: #33/#60 | Hmitpos_neg
# Running: #34/#60 | Npvf
# Running: #35/#60 | Oxytocin_1
# Running: #36/#60 | Oxytocin_2
# Running: #37/#60 | Oxytocin_3
# Running: #38/#60 | Oxytocin_4
# Running: #39/#60 | Pmch
# Running: #40/#60 | Sst_1_low
# Running: #41/#60 | Sst_2_high
# Running: #42/#60 | Sst_3_medium
# Running: #43/#60 | Trh_1_low
# Running: #44/#60 | Trh_2_medium
# Running: #45/#60 | Trh_3_high
# Running: #46/#60 | Vglut2_11
# Running: #47/#60 | Vglut2_12_Mgat4b
# Running: #48/#60 | Vglut2_13Ninl_Rfx5_Zfp346
# Running: #49/#60 | Vglut2_14_Col9a2
# Running: #50/#60 | Vglut2_15_Hcn1_6430411K18Rik
# Running: #51/#60 | Vglut2_2_Crhpos_neg
# Running: #52/#60 | Vglut2_3_Crhnegpos_neg_low
# Running: #53/#60 | Vglut2_4
# Running: #54/#60 | Vglut2_6_Prmt8_Ugdh
# Running: #55/#60 | Vglut2_7_Pgam_Snx12
# Running: #56/#60 | Vglut2_8
# Running: #57/#60 | Vglut2_9_Gpr149
# Running: #58/#60 | circadian_1_Vip_Grppos_neg
# Running: #59/#60 | circadian_2_Nms_VIPpos_neg
# Running: #60/#60 | circadian_3_Per2
# Writing files...
# Doing null computation. Permuting labels with seed(1).
# Running: #1/#60 | 1
# Running: #2/#60 | 2
# Running: #3/#60 | 3
# Running: #4/#60 | 4
# Running: #5/#60 | 6
# Running: #6/#60 | 7
# Running: #7/#60 | Adcyap1_1_Tac1
# Running: #8/#60 | Adcyap1_2
# Running: #9/#60 | Avp_1_high
# Running: #10/#60 | Avp_2_high
# Running: #11/#60 | Avp_3_medium
# Running: #12/#60 | Dopamine_1
# Running: #13/#60 | Dopamine_2_low_VMAT2
# Running: #14/#60 | Dopamine_3
# Running: #15/#60 | Dopamine_4
# Running: #16/#60 | GABA1
# Running: #17/#60 | GABA_10
# Running: #18/#60 | GABA_11_Nts_1
# Running: #19/#60 | GABA_12_Nts_2
# Running: #20/#60 | GABA_13_Galanin
# Running: #21/#60 | GABA_14_Npy_Agrp
# Running: #22/#60 | GABA_15_Npynegmedium
# Running: #23/#60 | GABA_2_Gucy1a3
# Running: #24/#60 | GABA_3_Crhpos_neg_Lhx6
# Running: #25/#60 | GABA_4_Crhpos_neg_Pgr15l
# Running: #26/#60 | GABA_5_Calcr_Lhx1
# Running: #27/#60 | GABA_6_Otof_Lhx1
# Running: #28/#60 | GABA_7_Pomcpos_neg
# Running: #29/#60 | GABA_8
# Running: #30/#60 | GABA_9
# Running: #31/#60 | Gadneglow_Gnrhneg_pos
# Running: #32/#60 | Hcrt
# Running: #33/#60 | Hmitpos_neg
# Running: #34/#60 | Npvf
# Running: #35/#60 | Oxytocin_1
# Running: #36/#60 | Oxytocin_2
# Running: #37/#60 | Oxytocin_3
# Running: #38/#60 | Oxytocin_4
# Running: #39/#60 | Pmch
# Running: #40/#60 | Sst_1_low
# Running: #41/#60 | Sst_2_high
# Running: #42/#60 | Sst_3_medium
# Running: #43/#60 | Trh_1_low
# Running: #44/#60 | Trh_2_medium
# Running: #45/#60 | Trh_3_high
# Running: #46/#60 | Vglut2_11
# Running: #47/#60 | Vglut2_12_Mgat4b
# Running: #48/#60 | Vglut2_13Ninl_Rfx5_Zfp346
# Running: #49/#60 | Vglut2_14_Col9a2
# Running: #50/#60 | Vglut2_15_Hcn1_6430411K18Rik
# Running: #51/#60 | Vglut2_2_Crhpos_neg
# Running: #52/#60 | Vglut2_3_Crhnegpos_neg_low
# Running: #53/#60 | Vglut2_4
# Running: #54/#60 | Vglut2_6_Prmt8_Ugdh
# Running: #55/#60 | Vglut2_7_Pgam_Snx12
# Running: #56/#60 | Vglut2_8
# Running: #57/#60 | Vglut2_9_Gpr149
# Running: #58/#60 | circadian_1_Vip_Grppos_neg
# Running: #59/#60 | circadian_2_Nms_VIPpos_neg
# Running: #60/#60 | circadian_3_Per2
# Writing files...

# %% [markdown]
# # Moffit2018

# %%
### Variables
dict_run = {os.path.join(output_dir, "moffitt2018"):"cell_type"} # {out_prefix:annotation_column}

# %%
[df_metadata, df_data] = utils_celldata_reader(input_dir, prefix="moffitt2018")
# Out:
# Reading UMI data...
# Done reading UMI data

# %%
df_ctc_log = ctc_log_normalize(df_data)
del df_data
# Out:
# Performning common transcript count (ctc) normalization and log-transformation on input data

# %%
for out_prefix in dict_run:
    print(out_prefix)
    annotations = df_metadata[dict_run[out_prefix]].values # get annotations
    df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)
    (df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)
    (df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)
# Out:
# /nfsdata/projects/jonatan/pub-perslab/timshel-bmicelltypes2019/tmp-data/expression-precalc/moffitt2018
# Splitting data frame into annotation groups
# Splitting annotation #1/#87 into group
# Splitting annotation #2/#87 into group
# Splitting annotation #3/#87 into group
# Splitting annotation #4/#87 into group
# Splitting annotation #5/#87 into group
# Splitting annotation #6/#87 into group
# Splitting annotation #7/#87 into group
# Splitting annotation #8/#87 into group
# Splitting annotation #9/#87 into group
# Splitting annotation #10/#87 into group
# Splitting annotation #11/#87 into group
# Splitting annotation #12/#87 into group
# Splitting annotation #13/#87 into group
# Splitting annotation #14/#87 into group
# Splitting annotation #15/#87 into group
# Splitting annotation #16/#87 into group
# Splitting annotation #17/#87 into group
# Splitting annotation #18/#87 into group
# Splitting annotation #19/#87 into group
# Splitting annotation #20/#87 into group
# Splitting annotation #21/#87 into group
# Splitting annotation #22/#87 into group
# Splitting annotation #23/#87 into group
# Splitting annotation #24/#87 into group
# Splitting annotation #25/#87 into group
# Splitting annotation #26/#87 into group
# Splitting annotation #27/#87 into group
# Splitting annotation #28/#87 into group
# Splitting annotation #29/#87 into group
# Splitting annotation #30/#87 into group
# Splitting annotation #31/#87 into group
# Splitting annotation #32/#87 into group
# Splitting annotation #33/#87 into group
# Splitting annotation #34/#87 into group
# Splitting annotation #35/#87 into group
# Splitting annotation #36/#87 into group
# Splitting annotation #37/#87 into group
# Splitting annotation #38/#87 into group
# Splitting annotation #39/#87 into group
# Splitting annotation #40/#87 into group
# Splitting annotation #41/#87 into group
# Splitting annotation #42/#87 into group
# Splitting annotation #43/#87 into group
# Splitting annotation #44/#87 into group
# Splitting annotation #45/#87 into group
# Splitting annotation #46/#87 into group
# Splitting annotation #47/#87 into group
# Splitting annotation #48/#87 into group
# Splitting annotation #49/#87 into group
# Splitting annotation #50/#87 into group
# Splitting annotation #51/#87 into group
# Splitting annotation #52/#87 into group
# Splitting annotation #53/#87 into group
# Splitting annotation #54/#87 into group
# Splitting annotation #55/#87 into group
# Splitting annotation #56/#87 into group
# Splitting annotation #57/#87 into group
# Splitting annotation #58/#87 into group
# Splitting annotation #59/#87 into group
# Splitting annotation #60/#87 into group
# Splitting annotation #61/#87 into group
# Splitting annotation #62/#87 into group
# Splitting annotation #63/#87 into group
# Splitting annotation #64/#87 into group
# Splitting annotation #65/#87 into group
# Splitting annotation #66/#87 into group
# Splitting annotation #67/#87 into group
# Splitting annotation #68/#87 into group
# Splitting annotation #69/#87 into group
# Splitting annotation #70/#87 into group
# Splitting annotation #71/#87 into group
# Splitting annotation #72/#87 into group
# Splitting annotation #73/#87 into group
# Splitting annotation #74/#87 into group
# Splitting annotation #75/#87 into group
# Splitting annotation #76/#87 into group
# Splitting annotation #77/#87 into group
# Splitting annotation #78/#87 into group
# Splitting annotation #79/#87 into group
# Splitting annotation #80/#87 into group
# Splitting annotation #81/#87 into group
# Splitting annotation #82/#87 into group
# Splitting annotation #83/#87 into group
# Splitting annotation #84/#87 into group
# Splitting annotation #85/#87 into group
# Splitting annotation #86/#87 into group
# Splitting annotation #87/#87 into group
# Running ANOVA
# gene 0 out of 27998
# /tools/anaconda/latest/lib/python3.7/site-packages/scipy/stats/stats.py:3235: RuntimeWarning: invalid value encountered in double_scalars
#   f = msb / msw
# gene 100 out of 27998
# gene 200 out of 27998
# gene 300 out of 27998
# gene 400 out of 27998
# gene 500 out of 27998
# gene 600 out of 27998
# gene 700 out of 27998
# gene 800 out of 27998
# gene 900 out of 27998
# gene 1000 out of 27998
# gene 1100 out of 27998
# gene 1200 out of 27998
# gene 1300 out of 27998
# gene 1400 out of 27998
# gene 1500 out of 27998
# gene 1600 out of 27998
# gene 1700 out of 27998
# gene 1800 out of 27998
# gene 1900 out of 27998
# gene 2000 out of 27998
# gene 2100 out of 27998
# gene 2200 out of 27998
# gene 2300 out of 27998
# gene 2400 out of 27998
# gene 2500 out of 27998
# gene 2600 out of 27998
# gene 2700 out of 27998
# gene 2800 out of 27998
# gene 2900 out of 27998
# gene 3000 out of 27998
# gene 3100 out of 27998
# gene 3200 out of 27998
# gene 3300 out of 27998
# gene 3400 out of 27998
# gene 3500 out of 27998
# gene 3600 out of 27998
# gene 3700 out of 27998
# gene 3800 out of 27998
# gene 3900 out of 27998
# gene 4000 out of 27998
# gene 4100 out of 27998
# gene 4200 out of 27998
# gene 4300 out of 27998
# gene 4400 out of 27998
# gene 4500 out of 27998
# gene 4600 out of 27998
# gene 4700 out of 27998
# gene 4800 out of 27998
# gene 4900 out of 27998
# gene 5000 out of 27998
# gene 5100 out of 27998
# gene 5200 out of 27998
# gene 5300 out of 27998
# gene 5400 out of 27998
# gene 5500 out of 27998
# gene 5600 out of 27998
# gene 5700 out of 27998
# gene 5800 out of 27998
# gene 5900 out of 27998
# gene 6000 out of 27998
# gene 6100 out of 27998
# gene 6200 out of 27998
# gene 6300 out of 27998
# gene 6400 out of 27998
# gene 6500 out of 27998
# gene 6600 out of 27998
# gene 6700 out of 27998
# gene 6800 out of 27998
# gene 6900 out of 27998
# gene 7000 out of 27998
# gene 7100 out of 27998
# gene 7200 out of 27998
# gene 7300 out of 27998
# gene 7400 out of 27998
# gene 7500 out of 27998
# gene 7600 out of 27998
# gene 7700 out of 27998
# gene 7800 out of 27998
# gene 7900 out of 27998
# gene 8000 out of 27998
# gene 8100 out of 27998
# gene 8200 out of 27998
# gene 8300 out of 27998
# gene 8400 out of 27998
# gene 8500 out of 27998
# gene 8600 out of 27998
# gene 8700 out of 27998
# gene 8800 out of 27998
# gene 8900 out of 27998
# gene 9000 out of 27998
# gene 9100 out of 27998
# gene 9200 out of 27998
# gene 9300 out of 27998
# gene 9400 out of 27998
# gene 9500 out of 27998
# gene 9600 out of 27998
# gene 9700 out of 27998
# gene 9800 out of 27998
# gene 9900 out of 27998
# gene 10000 out of 27998
# gene 10100 out of 27998
# gene 10200 out of 27998
# gene 10300 out of 27998
# gene 10400 out of 27998
# gene 10500 out of 27998
# gene 10600 out of 27998
# gene 10700 out of 27998
# gene 10800 out of 27998
# gene 10900 out of 27998
# gene 11000 out of 27998
# gene 11100 out of 27998
# gene 11200 out of 27998
# gene 11300 out of 27998
# gene 11400 out of 27998
# gene 11500 out of 27998
# gene 11600 out of 27998
# gene 11700 out of 27998
# gene 11800 out of 27998
# gene 11900 out of 27998
# gene 12000 out of 27998
# gene 12100 out of 27998
# gene 12200 out of 27998
# gene 12300 out of 27998
# gene 12400 out of 27998
# gene 12500 out of 27998
# gene 12600 out of 27998
# gene 12700 out of 27998
# gene 12800 out of 27998
# gene 12900 out of 27998
# gene 13000 out of 27998
# gene 13100 out of 27998
# gene 13200 out of 27998
# gene 13300 out of 27998
# gene 13400 out of 27998
# gene 13500 out of 27998
# gene 13600 out of 27998
# gene 13700 out of 27998
# gene 13800 out of 27998
# gene 13900 out of 27998
# gene 14000 out of 27998
# gene 14100 out of 27998
# gene 14200 out of 27998
# gene 14300 out of 27998
# gene 14400 out of 27998
# gene 14500 out of 27998
# gene 14600 out of 27998
# gene 14700 out of 27998
# gene 14800 out of 27998
# gene 14900 out of 27998
# gene 15000 out of 27998
# gene 15100 out of 27998
# gene 15200 out of 27998
# gene 15300 out of 27998
# gene 15400 out of 27998
# gene 15500 out of 27998
# gene 15600 out of 27998
# gene 15700 out of 27998
# gene 15800 out of 27998
# gene 15900 out of 27998
# gene 16000 out of 27998
# gene 16100 out of 27998
# gene 16200 out of 27998
# gene 16300 out of 27998
# gene 16400 out of 27998
# gene 16500 out of 27998
# gene 16600 out of 27998
# gene 16700 out of 27998
# gene 16800 out of 27998
# gene 16900 out of 27998
# gene 17000 out of 27998
# gene 17100 out of 27998
# gene 17200 out of 27998
# gene 17300 out of 27998
# gene 17400 out of 27998
# gene 17500 out of 27998
# gene 17600 out of 27998
# gene 17700 out of 27998
# gene 17800 out of 27998
# gene 17900 out of 27998
# gene 18000 out of 27998
# gene 18100 out of 27998
# gene 18200 out of 27998
# gene 18300 out of 27998
# gene 18400 out of 27998
# gene 18500 out of 27998
# gene 18600 out of 27998
# gene 18700 out of 27998
# gene 18800 out of 27998
# gene 18900 out of 27998
# gene 19000 out of 27998
# gene 19100 out of 27998
# gene 19200 out of 27998
# gene 19300 out of 27998
# gene 19400 out of 27998
# gene 19500 out of 27998
# gene 19600 out of 27998
# gene 19700 out of 27998
# gene 19800 out of 27998
# gene 19900 out of 27998
# gene 20000 out of 27998
# gene 20100 out of 27998
# gene 20200 out of 27998
# gene 20300 out of 27998
# gene 20400 out of 27998
# gene 20500 out of 27998
# gene 20600 out of 27998
# gene 20700 out of 27998
# gene 20800 out of 27998
# gene 20900 out of 27998
# gene 21000 out of 27998
# gene 21100 out of 27998
# gene 21200 out of 27998
# gene 21300 out of 27998
# gene 21400 out of 27998
# gene 21500 out of 27998
# gene 21600 out of 27998
# gene 21700 out of 27998
# gene 21800 out of 27998
# gene 21900 out of 27998
# gene 22000 out of 27998
# gene 22100 out of 27998
# gene 22200 out of 27998
# gene 22300 out of 27998
# gene 22400 out of 27998
# gene 22500 out of 27998
# gene 22600 out of 27998
# gene 22700 out of 27998
# gene 22800 out of 27998
# gene 22900 out of 27998
# gene 23000 out of 27998
# gene 23100 out of 27998
# gene 23200 out of 27998
# gene 23300 out of 27998
# gene 23400 out of 27998
# gene 23500 out of 27998
# gene 23600 out of 27998
# gene 23700 out of 27998
# gene 23800 out of 27998
# gene 23900 out of 27998
# gene 24000 out of 27998
# gene 24100 out of 27998
# gene 24200 out of 27998
# gene 24300 out of 27998
# gene 24400 out of 27998
# gene 24500 out of 27998
# gene 24600 out of 27998
# gene 24700 out of 27998
# gene 24800 out of 27998
# gene 24900 out of 27998
# gene 25000 out of 27998
# gene 25100 out of 27998
# gene 25200 out of 27998
# gene 25300 out of 27998
# gene 25400 out of 27998
# gene 25500 out of 27998
# gene 25600 out of 27998
# gene 25700 out of 27998
# gene 25800 out of 27998
# gene 25900 out of 27998
# gene 26000 out of 27998
# gene 26100 out of 27998
# gene 26200 out of 27998
# gene 26300 out of 27998
# gene 26400 out of 27998
# gene 26500 out of 27998
# gene 26600 out of 27998
# gene 26700 out of 27998
# gene 26800 out of 27998
# gene 26900 out of 27998
# gene 27000 out of 27998
# gene 27100 out of 27998
# gene 27200 out of 27998
# gene 27300 out of 27998
# gene 27400 out of 27998
# gene 27500 out of 27998
# gene 27600 out of 27998
# gene 27700 out of 27998
# gene 27800 out of 27998
# gene 27900 out of 27998
# Writing out file...
# Number of genes sporadically expressed (pvalue > 0.00001): 5333
# Running: #1/#87 | Astrocytes_1
# Running: #2/#87 | Astrocytes_2
# Running: #3/#87 | Endothelial_1
# Running: #4/#87 | Endothelial_2
# Running: #5/#87 | Endothelial_3
# Running: #6/#87 | Ependymal_1
# Running: #7/#87 | Fibroblast_1
# Running: #8/#87 | Immature_oligodendrocyte_1
# Running: #9/#87 | Immature_oligodendrocyte_2
# Running: #10/#87 | Macrophage_1
# Running: #11/#87 | Mature_oligodendrocyte_1
# Running: #12/#87 | Mature_oligodendrocyte_2
# Running: #13/#87 | Mature_oligodendrocyte_3
# Running: #14/#87 | Mature_oligodendrocyte_4
# Running: #15/#87 | Mature_oligodendrocyte_5
# Running: #16/#87 | Mature_oligodendrocyte_6
# Running: #17/#87 | Microglia_1
# Running: #18/#87 | Microglia_2
# Running: #19/#87 | Mural_1
# Running: #20/#87 | Mural_2
# Running: #21/#87 | Newly_formed_oligodendrocyte_1
# Running: #22/#87 | e10_Glut_Meis2
# Running: #23/#87 | e11_Glut_Shox2
# Running: #24/#87 | e12_Nos1_Foxp2
# Running: #25/#87 | e13_Ghrh_C1ql1
# Running: #26/#87 | e15_Ucn3_Brs3
# Running: #27/#87 | e16_Sst_Cartpt
# Running: #28/#87 | e17_Th_Adcyap1
# Running: #29/#87 | e19_Ghrh_Trh
# Running: #30/#87 | e1_Glut
# Running: #31/#87 | e20_Crh
# Running: #32/#87 | e21_Glut_Rxpf3
# Running: #33/#87 | e22_Gal_Ucn3
# Running: #34/#87 | e23_Reln_Etv1
# Running: #35/#87 | e24_Gal_Rxfp1_
# Running: #36/#87 | e2_Tac1_Fezf1
# Running: #37/#87 | e3_Cartpt_Isl1
# Running: #38/#87 | e4_Trh_Angpt1
# Running: #39/#87 | e5_Adcyap1_Nkx2.1
# Running: #40/#87 | e6_Nos1_Trp73
# Running: #41/#87 | e7_Reln_C1ql1
# Running: #42/#87 | e8_Cck_Ebf3
# Running: #43/#87 | e9_Glut_Tcf7l2
# Running: #44/#87 | h1_Gaba_Slc17a6
# Running: #45/#87 | h2_Nts_Slc17a8
# Running: #46/#87 | h3_Slc32a1_Gsc
# Running: #47/#87 | i10_Tac1_Nts
# Running: #48/#87 | i11_Gaba
# Running: #49/#87 | i12_Gaba
# Running: #50/#87 | i13_Gaba
# Running: #51/#87 | i14_Avp_Cck
# Running: #52/#87 | i15_Gaba
# Running: #53/#87 | i16_Gal_Th
# Running: #54/#87 | i17_Th_Nos1
# Running: #55/#87 | i18_Gal_Tac2
# Running: #56/#87 | i1_Gaba
# Running: #57/#87 | i20_Gal_Moxd1
# Running: #58/#87 | i21_Sst_Pou3f3
# Running: #59/#87 | i22_Gal_Pmaip1
# Running: #60/#87 | i23_Crh_Nts
# Running: #61/#87 | i24_Nmu
# Running: #62/#87 | i25_Npy_Etv1
# Running: #63/#87 | i26_Tac1_Prok2
# Running: #64/#87 | i27_Th_Trh
# Running: #65/#87 | i28_Gaba_Six6
# Running: #66/#87 | i29_Gaba_Igsf1
# Running: #67/#87 | i2_Tac1_Pdyn
# Running: #68/#87 | i30_Vip
# Running: #69/#87 | i31_Calca
# Running: #70/#87 | i32_Sst_Npy
# Running: #71/#87 | i35_Crh_Tac2
# Running: #72/#87 | i37_Bdnf_Chrm2
# Running: #73/#87 | i38_Kiss1_Th
# Running: #74/#87 | i39_Gaba
# Running: #75/#87 | i3_Penk_Nts
# Running: #76/#87 | i40_Sst_Reln
# Running: #77/#87 | i41_Npy_Penk
# Running: #78/#87 | i42_Pthlh
# Running: #79/#87 | i43_Chat
# Running: #80/#87 | i44_Th_Cxcl14
# Running: #81/#87 | i45_Bdnf_Pmaip1
# Running: #82/#87 | i4_Gaba_Mylk
# Running: #83/#87 | i5_Gaba_Pou3f3
# Running: #84/#87 | i6_Avp_Nms
# Running: #85/#87 | i7_Gaba
# Running: #86/#87 | i8_Gal_Amigo2
# Running: #87/#87 | i9_Gaba
# Writing files...
# Doing null computation. Permuting labels with seed(1).
# Running: #1/#87 | Astrocytes_1
# Running: #2/#87 | Astrocytes_2
# Running: #3/#87 | Endothelial_1
# Running: #4/#87 | Endothelial_2
# Running: #5/#87 | Endothelial_3
# Running: #6/#87 | Ependymal_1
# Running: #7/#87 | Fibroblast_1
# Running: #8/#87 | Immature_oligodendrocyte_1
# Running: #9/#87 | Immature_oligodendrocyte_2
# Running: #10/#87 | Macrophage_1
# Running: #11/#87 | Mature_oligodendrocyte_1
# Running: #12/#87 | Mature_oligodendrocyte_2
# Running: #13/#87 | Mature_oligodendrocyte_3
# Running: #14/#87 | Mature_oligodendrocyte_4
# Running: #15/#87 | Mature_oligodendrocyte_5
# Running: #16/#87 | Mature_oligodendrocyte_6
# Running: #17/#87 | Microglia_1
# Running: #18/#87 | Microglia_2
# Running: #19/#87 | Mural_1
# Running: #20/#87 | Mural_2
# Running: #21/#87 | Newly_formed_oligodendrocyte_1
# Running: #22/#87 | e10_Glut_Meis2
# Running: #23/#87 | e11_Glut_Shox2
# Running: #24/#87 | e12_Nos1_Foxp2
# Running: #25/#87 | e13_Ghrh_C1ql1
# Running: #26/#87 | e15_Ucn3_Brs3
# Running: #27/#87 | e16_Sst_Cartpt
# Running: #28/#87 | e17_Th_Adcyap1
# Running: #29/#87 | e19_Ghrh_Trh
# Running: #30/#87 | e1_Glut
# Running: #31/#87 | e20_Crh
# Running: #32/#87 | e21_Glut_Rxpf3
# Running: #33/#87 | e22_Gal_Ucn3
# Running: #34/#87 | e23_Reln_Etv1
# Running: #35/#87 | e24_Gal_Rxfp1_
# Running: #36/#87 | e2_Tac1_Fezf1
# Running: #37/#87 | e3_Cartpt_Isl1
# Running: #38/#87 | e4_Trh_Angpt1
# Running: #39/#87 | e5_Adcyap1_Nkx2.1
# Running: #40/#87 | e6_Nos1_Trp73
# Running: #41/#87 | e7_Reln_C1ql1
# Running: #42/#87 | e8_Cck_Ebf3
# Running: #43/#87 | e9_Glut_Tcf7l2
# Running: #44/#87 | h1_Gaba_Slc17a6
# Running: #45/#87 | h2_Nts_Slc17a8
# Running: #46/#87 | h3_Slc32a1_Gsc
# Running: #47/#87 | i10_Tac1_Nts
# Running: #48/#87 | i11_Gaba
# Running: #49/#87 | i12_Gaba
# Running: #50/#87 | i13_Gaba
# Running: #51/#87 | i14_Avp_Cck
# Running: #52/#87 | i15_Gaba
# Running: #53/#87 | i16_Gal_Th
# Running: #54/#87 | i17_Th_Nos1
# Running: #55/#87 | i18_Gal_Tac2
# Running: #56/#87 | i1_Gaba
# Running: #57/#87 | i20_Gal_Moxd1
# Running: #58/#87 | i21_Sst_Pou3f3
# Running: #59/#87 | i22_Gal_Pmaip1
# Running: #60/#87 | i23_Crh_Nts
# Running: #61/#87 | i24_Nmu
# Running: #62/#87 | i25_Npy_Etv1
# Running: #63/#87 | i26_Tac1_Prok2
# Running: #64/#87 | i27_Th_Trh
# Running: #65/#87 | i28_Gaba_Six6
# Running: #66/#87 | i29_Gaba_Igsf1
# Running: #67/#87 | i2_Tac1_Pdyn
# Running: #68/#87 | i30_Vip
# Running: #69/#87 | i31_Calca
# Running: #70/#87 | i32_Sst_Npy
# Running: #71/#87 | i35_Crh_Tac2
# Running: #72/#87 | i37_Bdnf_Chrm2
# Running: #73/#87 | i38_Kiss1_Th
# Running: #74/#87 | i39_Gaba
# Running: #75/#87 | i3_Penk_Nts
# Running: #76/#87 | i40_Sst_Reln
# Running: #77/#87 | i41_Npy_Penk
# Running: #78/#87 | i42_Pthlh
# Running: #79/#87 | i43_Chat
# Running: #80/#87 | i44_Th_Cxcl14
# Running: #81/#87 | i45_Bdnf_Pmaip1
# Running: #82/#87 | i4_Gaba_Mylk
# Running: #83/#87 | i5_Gaba_Pou3f3
# Running: #84/#87 | i6_Avp_Nms
# Running: #85/#87 | i7_Gaba
# Running: #86/#87 | i8_Gal_Amigo2
# Running: #87/#87 | i9_Gaba
# Writing files...
