# %%
import os
import sys

import numpy as np
import pandas as pd

# %%
# lib_path = os.path.abspath(os.path.pardir) # same as os.path.abspath("..")
lib_path = "/projects/timshel/sc-genetics/sc-genetics/src/lib"
sys.path.insert(1, lib_path)
from sem_pre_calculation import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Constants

# %%
out_prefix = "tabula_muris"

# %% [markdown]
# ### Read data

# %%
### Metadata
file_metadata = "/scratch/data-for_fast_access/pub-others/tabula_muris_180920/tabula_muris.metadata.csv"
df_metadata = pd.read_csv(file_metadata, index_col=False)
df_metadata.head()
# Out:
#                    cell_id  nGene   nReads tissue subtissue_clean  \
# 0    A1.B000126.3_39_F.1.1   3125   599257   Skin         Telogen
# 1    A1.B003283.3_38_F.1.1   5543  2585048   Skin         Telogen
# 2  A1.MAA000435.3_10_M.1.1   5023  1748535   Skin          Anagen
# 3   A1.MAA000549.3_8_M.1.1   3846   309793   Skin          Anagen
# 4  A1.MAA000614.3_10_M.1.1   3249  1044110   Skin         Telogen
#
#                   celltype               tissue_celltype  \
# 0           epidermal cell           Skin.epidermal cell
# 1           epidermal cell           Skin.epidermal cell
# 2  basal cell of epidermis  Skin.basal cell of epidermis
# 3           epidermal cell           Skin.epidermal cell
# 4  basal cell of epidermis  Skin.basal cell of epidermis
#
#               tissue_subtissue_celltype
# 0           Skin.Telogen.epidermal cell
# 1           Skin.Telogen.epidermal cell
# 2   Skin.Anagen.basal cell of epidermis
# 3            Skin.Anagen.epidermal cell
# 4  Skin.Telogen.basal cell of epidermis

# %%
### Data
file_data = "/scratch/data-for_fast_access/pub-others/tabula_muris_180920/tabula_muris.umi.csv.gz"
df_data = pd.read_csv(file_data, index_col=False) # this takes 12-14 min for tabula_muris! (Pandas is slow!)

# %%
df_data.set_index("gene", inplace=True) # set index
df_data.head()
# Out:
#                A1.B000126.3_39_F.1.1  A1.B003283.3_38_F.1.1  \
# gene
# 0610005C13Rik                      0                      0
# 0610007C21Rik                    265                   1026
# 0610007L01Rik                      1                     35
# 0610007N19Rik                      0                      0
# 0610007P08Rik                      0                      0
#
#                A1.MAA000435.3_10_M.1.1  A1.MAA000549.3_8_M.1.1  \
# gene
# 0610005C13Rik                        0                       0
# 0610007C21Rik                        0                      48
# 0610007L01Rik                        4                       0
# 0610007N19Rik                        0                       0
# 0610007P08Rik                        0                      10
#
#                A1.MAA000614.3_10_M.1.1  A1.MAA000938.3_8_M.1.1  \
# gene
# 0610005C13Rik                        0                       0
# 0610007C21Rik                       26                      87
# 0610007L01Rik                      186                       2
# 0610007N19Rik                        0                       0
# 0610007P08Rik                        0                       0
#
#                A10.B003283.3_38_F.1.1  A11.B000126.3_39_F.1.1  \
# gene
# 0610005C13Rik                       0                       0
# 0610007C21Rik                      36                     245
# 0610007L01Rik                       0                       0
# 0610007N19Rik                       0                       0
# 0610007P08Rik                     110                       0
#
#                A12.B000126.3_39_F.1.1  A12.B003283.3_38_F.1.1  \
# gene
# 0610005C13Rik                       0                       0
# 0610007C21Rik                       0                     245
# 0610007L01Rik                       0                       0
# 0610007N19Rik                       0                       0
# 0610007P08Rik                       0                       0
#
#                         ...             O6.MAA001847.3_39_F.1.1  \
# gene                    ...
# 0610005C13Rik           ...                                   0
# 0610007C21Rik           ...                                  74
# 0610007L01Rik           ...                                  72
# 0610007N19Rik           ...                                  11
# 0610007P08Rik           ...                                   0
#
#                O7.MAA001847.3_39_F.1.1  P2.MAA001847.3_39_F.1.1  \
# gene
# 0610005C13Rik                        0                        0
# 0610007C21Rik                        0                      164
# 0610007L01Rik                        4                        7
# 0610007N19Rik                        0                        0
# 0610007P08Rik                        0                        0
#
#                P3.MAA000839.3_11_M.1.1  P4.MAA000526.3_9_M.1.1  \
# gene
# 0610005C13Rik                        0                       0
# 0610007C21Rik                        0                      51
# 0610007L01Rik                        0                       0
# 0610007N19Rik                        0                       0
# 0610007P08Rik                        0                       0
#
#                P4.MAA000839.3_11_M.1.1  P5.MAA000526.3_9_M.1.1  \
# gene
# 0610005C13Rik                        0                       0
# 0610007C21Rik                      315                       1
# 0610007L01Rik                        0                       0
# 0610007N19Rik                        3                       0
# 0610007P08Rik                        0                       0
#
#                P5.MAA001847.3_39_F.1.1  P6.MAA001847.3_39_F.1.1  \
# gene
# 0610005C13Rik                        0                        0
# 0610007C21Rik                        0                      193
# 0610007L01Rik                       15                        0
# 0610007N19Rik                        1                        0
# 0610007P08Rik                        0                       53
#
#                P9.MAA001847.3_39_F.1.1
# gene
# 0610005C13Rik                        0
# 0610007C21Rik                        0
# 0610007L01Rik                       33
# 0610007N19Rik                        0
# 0610007P08Rik                        0
#
# [5 rows x 44949 columns]

# %%
### [*IMPORTANT*] Check that all metadata cell_ids are identical to data columnnames. 
### We need to ensure this before we can use the metadata cell-types as annotations.
np.all(df_data.columns.values == df_metadata["cell_id"].values) # ---> True
# Out:
# True

# %% [markdown]
# ### CTC log normalize

# %%
df_ctc_log = ctc_log_normalize(df_data)
# Out:
# Performning common transcript count (ctc) normalization and log-transformation on input data

# %% [markdown]
# ### Set annotations

# %%
annotations = df_metadata["tissue_celltype"].values
annotations[:5]
# Out:
# array(['Skin.epidermal cell', 'Skin.epidermal cell',
#        'Skin.basal cell of epidermis', 'Skin.epidermal cell',
#        'Skin.basal cell of epidermis'], dtype=object)

# %% [markdown]
# ### Anova

# %%
df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)
# Number of genes sporadically expressed (pvalue > 0.00001, Skene cut-off): 2365
# Out:
# Splitting data frame into annotation groups
# Splitting annotation #1/#115 into group
# Splitting annotation #2/#115 into group
# Splitting annotation #3/#115 into group
# Splitting annotation #4/#115 into group
# Splitting annotation #5/#115 into group
# Splitting annotation #6/#115 into group
# Splitting annotation #7/#115 into group
# Splitting annotation #8/#115 into group
# Splitting annotation #9/#115 into group
# Splitting annotation #10/#115 into group
# Splitting annotation #11/#115 into group
# Splitting annotation #12/#115 into group
# Splitting annotation #13/#115 into group
# Splitting annotation #14/#115 into group
# Splitting annotation #15/#115 into group
# Splitting annotation #16/#115 into group
# Splitting annotation #17/#115 into group
# Splitting annotation #18/#115 into group
# Splitting annotation #19/#115 into group
# Splitting annotation #20/#115 into group
# Splitting annotation #21/#115 into group
# Splitting annotation #22/#115 into group
# Splitting annotation #23/#115 into group
# Splitting annotation #24/#115 into group
# Splitting annotation #25/#115 into group
# Splitting annotation #26/#115 into group
# Splitting annotation #27/#115 into group
# Splitting annotation #28/#115 into group
# Splitting annotation #29/#115 into group
# Splitting annotation #30/#115 into group
# Splitting annotation #31/#115 into group
# Splitting annotation #32/#115 into group
# Splitting annotation #33/#115 into group
# Splitting annotation #34/#115 into group
# Splitting annotation #35/#115 into group
# Splitting annotation #36/#115 into group
# Splitting annotation #37/#115 into group
# Splitting annotation #38/#115 into group
# Splitting annotation #39/#115 into group
# Splitting annotation #40/#115 into group
# Splitting annotation #41/#115 into group
# Splitting annotation #42/#115 into group
# Splitting annotation #43/#115 into group
# Splitting annotation #44/#115 into group
# Splitting annotation #45/#115 into group
# Splitting annotation #46/#115 into group
# Splitting annotation #47/#115 into group
# Splitting annotation #48/#115 into group
# Splitting annotation #49/#115 into group
# Splitting annotation #50/#115 into group
# Splitting annotation #51/#115 into group
# Splitting annotation #52/#115 into group
# Splitting annotation #53/#115 into group
# Splitting annotation #54/#115 into group
# Splitting annotation #55/#115 into group
# Splitting annotation #56/#115 into group
# Splitting annotation #57/#115 into group
# Splitting annotation #58/#115 into group
# Splitting annotation #59/#115 into group
# Splitting annotation #60/#115 into group
# Splitting annotation #61/#115 into group
# Splitting annotation #62/#115 into group
# Splitting annotation #63/#115 into group
# Splitting annotation #64/#115 into group
# Splitting annotation #65/#115 into group
# Splitting annotation #66/#115 into group
# Splitting annotation #67/#115 into group
# Splitting annotation #68/#115 into group
# Splitting annotation #69/#115 into group
# Splitting annotation #70/#115 into group
# Splitting annotation #71/#115 into group
# Splitting annotation #72/#115 into group
# Splitting annotation #73/#115 into group
# Splitting annotation #74/#115 into group
# Splitting annotation #75/#115 into group
# Splitting annotation #76/#115 into group
# Splitting annotation #77/#115 into group
# Splitting annotation #78/#115 into group
# Splitting annotation #79/#115 into group
# Splitting annotation #80/#115 into group
# Splitting annotation #81/#115 into group
# Splitting annotation #82/#115 into group
# Splitting annotation #83/#115 into group
# Splitting annotation #84/#115 into group
# Splitting annotation #85/#115 into group
# Splitting annotation #86/#115 into group
# Splitting annotation #87/#115 into group
# Splitting annotation #88/#115 into group
# Splitting annotation #89/#115 into group
# Splitting annotation #90/#115 into group
# Splitting annotation #91/#115 into group
# Splitting annotation #92/#115 into group
# Splitting annotation #93/#115 into group
# Splitting annotation #94/#115 into group
# Splitting annotation #95/#115 into group
# Splitting annotation #96/#115 into group
# Splitting annotation #97/#115 into group
# Splitting annotation #98/#115 into group
# Splitting annotation #99/#115 into group
# Splitting annotation #100/#115 into group
# Splitting annotation #101/#115 into group
# Splitting annotation #102/#115 into group
# Splitting annotation #103/#115 into group
# Splitting annotation #104/#115 into group
# Splitting annotation #105/#115 into group
# Splitting annotation #106/#115 into group
# Splitting annotation #107/#115 into group
# Splitting annotation #108/#115 into group
# Splitting annotation #109/#115 into group
# Splitting annotation #110/#115 into group
# Splitting annotation #111/#115 into group
# Splitting annotation #112/#115 into group
# Splitting annotation #113/#115 into group
# Splitting annotation #114/#115 into group
# Splitting annotation #115/#115 into group
# Number of genes sporadically expressed (pvalue > 0.00001, Skene cut-off): 2365

# %%
df_anova.head()
### Define sporatically expressed genes
# genes_sporadically = df_anova[df_anova['pvalue'] > 0.00001].index
# genes_sporadically
# Out:
#                pvalue  statistic
# gene
# 4930524C18Rik     1.0   0.145111
# Tmem225           1.0   0.181884
# Mir1948           1.0   0.246055
# 7420426K07Rik     1.0   0.243265
# Mir1912           1.0   0.222707

# %%
df_anova.to_csv("{}.pre_calc.sporadically_expressed_genes.anova.csv.gz".format(out_prefix), compression="gzip")

# %% [markdown]
# ### SEM pre-calculation

# %%
(df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)
# Out:
# Running: #1/#115 | Bladder.bladder cell
# Running: #2/#115 | Bladder.bladder urothelial cell
# Running: #3/#115 | Brain_Myeloid.macrophage
# Running: #4/#115 | Brain_Myeloid.microglial cell
# Running: #5/#115 | Brain_Non-Myeloid.Bergmann glial cell
# Running: #6/#115 | Brain_Non-Myeloid.astrocyte
# Running: #7/#115 | Brain_Non-Myeloid.brain pericyte
# Running: #8/#115 | Brain_Non-Myeloid.endothelial cell
# Running: #9/#115 | Brain_Non-Myeloid.neuron
# Running: #10/#115 | Brain_Non-Myeloid.oligodendrocyte
# Running: #11/#115 | Brain_Non-Myeloid.oligodendrocyte precursor cell
# Running: #12/#115 | Fat.B cell
# Running: #13/#115 | Fat.T cell
# Running: #14/#115 | Fat.endothelial cell
# Running: #15/#115 | Fat.mesenchymal stem cell of adipose
# Running: #16/#115 | Fat.myeloid cell
# Running: #17/#115 | Fat.natural killer cell
# Running: #18/#115 | Fat.unknown cell type
# Running: #19/#115 | Heart.cardiac muscle cell
# Running: #20/#115 | Heart.endocardial cell
# Running: #21/#115 | Heart.endothelial cell
# Running: #22/#115 | Heart.erythrocyte
# Running: #23/#115 | Heart.fibroblast
# Running: #24/#115 | Heart.leukocyte
# Running: #25/#115 | Heart.myofibroblast cell
# Running: #26/#115 | Heart.professional antigen presenting cell
# Running: #27/#115 | Heart.smooth muscle cell
# Running: #28/#115 | Heart.unknown cell type
# Running: #29/#115 | Kidney.endothelial cell
# Running: #30/#115 | Kidney.epithelial cell of proximal tubule
# Running: #31/#115 | Kidney.kidney collecting duct epithelial cell
# Running: #32/#115 | Kidney.leukocyte
# Running: #33/#115 | Kidney.macrophage
# Running: #34/#115 | Large_Intestine.Brush cell of epithelium proper of large intestine
# Running: #35/#115 | Large_Intestine.enterocyte of epithelium of large intestine
# Running: #36/#115 | Large_Intestine.enteroendocrine cell
# Running: #37/#115 | Large_Intestine.epithelial cell of large intestine
# Running: #38/#115 | Large_Intestine.large intestine goblet cell
# Running: #39/#115 | Limb_Muscle.B cell
# Running: #40/#115 | Limb_Muscle.T cell
# Running: #41/#115 | Limb_Muscle.endothelial cell
# Running: #42/#115 | Limb_Muscle.lymphocyte
# Running: #43/#115 | Limb_Muscle.macrophage
# Running: #44/#115 | Limb_Muscle.mesenchymal stem cell
# Running: #45/#115 | Limb_Muscle.skeletal muscle satellite cell
# Running: #46/#115 | Limb_Muscle.skeletal muscle satellite stem cell
# Running: #47/#115 | Liver.B cell
# Running: #48/#115 | Liver.Kupffer cell
# Running: #49/#115 | Liver.endothelial cell of hepatic sinusoid
# Running: #50/#115 | Liver.hepatocyte
# Running: #51/#115 | Liver.natural killer cell
# Running: #52/#115 | Lung.B cell
# Running: #53/#115 | Lung.T cell
# Running: #54/#115 | Lung.ciliated columnar cell of tracheobronchial tree
# Running: #55/#115 | Lung.classical monocyte
# Running: #56/#115 | Lung.epithelial cell of lung
# Running: #57/#115 | Lung.leukocyte
# Running: #58/#115 | Lung.lung endothelial cell
# Running: #59/#115 | Lung.monocyte
# Running: #60/#115 | Lung.myeloid cell
# Running: #61/#115 | Lung.natural killer cell
# Running: #62/#115 | Lung.stromal cell
# Running: #63/#115 | Lung.unknown cell type
# Running: #64/#115 | Mammary_Gland.basal cell
# Running: #65/#115 | Mammary_Gland.endothelial cell
# Running: #66/#115 | Mammary_Gland.luminal epithelial cell of mammary gland
# Running: #67/#115 | Mammary_Gland.stromal cell
# Running: #68/#115 | Marrow.B cell
# Running: #69/#115 | Marrow.Slamf1-negative multipotent progenitor cell
# Running: #70/#115 | Marrow.Slamf1-positive multipotent progenitor cell
# Running: #71/#115 | Marrow.basophil
# Running: #72/#115 | Marrow.common lymphoid progenitor
# Running: #73/#115 | Marrow.granulocyte
# Running: #74/#115 | Marrow.granulocyte monocyte progenitor cell
# Running: #75/#115 | Marrow.granulocytopoietic cell
# Running: #76/#115 | Marrow.hematopoietic precursor cell
# Running: #77/#115 | Marrow.immature B cell
# Running: #78/#115 | Marrow.immature NK T cell
# Running: #79/#115 | Marrow.immature T cell
# Running: #80/#115 | Marrow.immature natural killer cell
# Running: #81/#115 | Marrow.late pro-B cell
# Running: #82/#115 | Marrow.macrophage
# Running: #83/#115 | Marrow.mature natural killer cell
# Running: #84/#115 | Marrow.megakaryocyte-erythroid progenitor cell
# Running: #85/#115 | Marrow.monocyte
# Running: #86/#115 | Marrow.naive B cell
# Running: #87/#115 | Marrow.pre-natural killer cell
# Running: #88/#115 | Marrow.precursor B cell
# Running: #89/#115 | Marrow.regulatory T cell
# Running: #90/#115 | Pancreas.endothelial cell
# Running: #91/#115 | Pancreas.leukocyte
# Running: #92/#115 | Pancreas.pancreatic A cell
# Running: #93/#115 | Pancreas.pancreatic D cell
# Running: #94/#115 | Pancreas.pancreatic PP cell
# Running: #95/#115 | Pancreas.pancreatic acinar cell
# Running: #96/#115 | Pancreas.pancreatic ductal cell
# Running: #97/#115 | Pancreas.pancreatic stellate cell
# Running: #98/#115 | Pancreas.type B pancreatic cell
# Running: #99/#115 | Skin.basal cell of epidermis
# Running: #100/#115 | Skin.epidermal cell
# Running: #101/#115 | Skin.keratinocyte stem cell
# Running: #102/#115 | Skin.leukocyte
# Running: #103/#115 | Skin.stem cell of epidermis
# Running: #104/#115 | Spleen.B cell
# Running: #105/#115 | Spleen.T cell
# Running: #106/#115 | Spleen.macrophage
# Running: #107/#115 | Thymus.DN1 thymic pro-T cell
# Running: #108/#115 | Thymus.immature T cell
# Running: #109/#115 | Thymus.leukocyte
# Running: #110/#115 | Tongue.basal cell of epidermis
# Running: #111/#115 | Tongue.keratinocyte
# Running: #112/#115 | Trachea.blood cell
# Running: #113/#115 | Trachea.endothelial cell
# Running: #114/#115 | Trachea.epithelial cell
# Running: #115/#115 | Trachea.mesenchymal cell
# Writing files...

# %%
(df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)
# Out:
# Doing null computation. Permuting labels with seed(1).
# Running: #1/#115 | Bladder.bladder cell
# Running: #2/#115 | Bladder.bladder urothelial cell
# Running: #3/#115 | Brain_Myeloid.macrophage
# Running: #4/#115 | Brain_Myeloid.microglial cell
# Running: #5/#115 | Brain_Non-Myeloid.Bergmann glial cell
# Running: #6/#115 | Brain_Non-Myeloid.astrocyte
# Running: #7/#115 | Brain_Non-Myeloid.brain pericyte
# Running: #8/#115 | Brain_Non-Myeloid.endothelial cell
# Running: #9/#115 | Brain_Non-Myeloid.neuron
# Running: #10/#115 | Brain_Non-Myeloid.oligodendrocyte
# Running: #11/#115 | Brain_Non-Myeloid.oligodendrocyte precursor cell
# Running: #12/#115 | Fat.B cell
# Running: #13/#115 | Fat.T cell
# Running: #14/#115 | Fat.endothelial cell
# Running: #15/#115 | Fat.mesenchymal stem cell of adipose
# Running: #16/#115 | Fat.myeloid cell
# Running: #17/#115 | Fat.natural killer cell
# Running: #18/#115 | Fat.unknown cell type
# Running: #19/#115 | Heart.cardiac muscle cell
# Running: #20/#115 | Heart.endocardial cell
# Running: #21/#115 | Heart.endothelial cell
# Running: #22/#115 | Heart.erythrocyte
# Running: #23/#115 | Heart.fibroblast
# Running: #24/#115 | Heart.leukocyte
# Running: #25/#115 | Heart.myofibroblast cell
# Running: #26/#115 | Heart.professional antigen presenting cell
# Running: #27/#115 | Heart.smooth muscle cell
# Running: #28/#115 | Heart.unknown cell type
# Running: #29/#115 | Kidney.endothelial cell
# Running: #30/#115 | Kidney.epithelial cell of proximal tubule
# Running: #31/#115 | Kidney.kidney collecting duct epithelial cell
# Running: #32/#115 | Kidney.leukocyte
# Running: #33/#115 | Kidney.macrophage
# Running: #34/#115 | Large_Intestine.Brush cell of epithelium proper of large intestine
# Running: #35/#115 | Large_Intestine.enterocyte of epithelium of large intestine
# Running: #36/#115 | Large_Intestine.enteroendocrine cell
# Running: #37/#115 | Large_Intestine.epithelial cell of large intestine
# Running: #38/#115 | Large_Intestine.large intestine goblet cell
# Running: #39/#115 | Limb_Muscle.B cell
# Running: #40/#115 | Limb_Muscle.T cell
# Running: #41/#115 | Limb_Muscle.endothelial cell
# Running: #42/#115 | Limb_Muscle.lymphocyte
# Running: #43/#115 | Limb_Muscle.macrophage
# Running: #44/#115 | Limb_Muscle.mesenchymal stem cell
# Running: #45/#115 | Limb_Muscle.skeletal muscle satellite cell
# Running: #46/#115 | Limb_Muscle.skeletal muscle satellite stem cell
# Running: #47/#115 | Liver.B cell
# Running: #48/#115 | Liver.Kupffer cell
# Running: #49/#115 | Liver.endothelial cell of hepatic sinusoid
# Running: #50/#115 | Liver.hepatocyte
# Running: #51/#115 | Liver.natural killer cell
# Running: #52/#115 | Lung.B cell
# Running: #53/#115 | Lung.T cell
# Running: #54/#115 | Lung.ciliated columnar cell of tracheobronchial tree
# Running: #55/#115 | Lung.classical monocyte
# Running: #56/#115 | Lung.epithelial cell of lung
# Running: #57/#115 | Lung.leukocyte
# Running: #58/#115 | Lung.lung endothelial cell
# Running: #59/#115 | Lung.monocyte
# Running: #60/#115 | Lung.myeloid cell
# Running: #61/#115 | Lung.natural killer cell
# Running: #62/#115 | Lung.stromal cell
# Running: #63/#115 | Lung.unknown cell type
# Running: #64/#115 | Mammary_Gland.basal cell
# Running: #65/#115 | Mammary_Gland.endothelial cell
# Running: #66/#115 | Mammary_Gland.luminal epithelial cell of mammary gland
# Running: #67/#115 | Mammary_Gland.stromal cell
# Running: #68/#115 | Marrow.B cell
# Running: #69/#115 | Marrow.Slamf1-negative multipotent progenitor cell
# Running: #70/#115 | Marrow.Slamf1-positive multipotent progenitor cell
# Running: #71/#115 | Marrow.basophil
# Running: #72/#115 | Marrow.common lymphoid progenitor
# Running: #73/#115 | Marrow.granulocyte
# Running: #74/#115 | Marrow.granulocyte monocyte progenitor cell
# Running: #75/#115 | Marrow.granulocytopoietic cell
# Running: #76/#115 | Marrow.hematopoietic precursor cell
# Running: #77/#115 | Marrow.immature B cell
# Running: #78/#115 | Marrow.immature NK T cell
# Running: #79/#115 | Marrow.immature T cell
# Running: #80/#115 | Marrow.immature natural killer cell
# Running: #81/#115 | Marrow.late pro-B cell
# Running: #82/#115 | Marrow.macrophage
# Running: #83/#115 | Marrow.mature natural killer cell
# Running: #84/#115 | Marrow.megakaryocyte-erythroid progenitor cell
# Running: #85/#115 | Marrow.monocyte
# Running: #86/#115 | Marrow.naive B cell
# Running: #87/#115 | Marrow.pre-natural killer cell
# Running: #88/#115 | Marrow.precursor B cell
# Running: #89/#115 | Marrow.regulatory T cell
# Running: #90/#115 | Pancreas.endothelial cell
# Running: #91/#115 | Pancreas.leukocyte
# Running: #92/#115 | Pancreas.pancreatic A cell
# Running: #93/#115 | Pancreas.pancreatic D cell
# Running: #94/#115 | Pancreas.pancreatic PP cell
# Running: #95/#115 | Pancreas.pancreatic acinar cell
# Running: #96/#115 | Pancreas.pancreatic ductal cell
# Running: #97/#115 | Pancreas.pancreatic stellate cell
# Running: #98/#115 | Pancreas.type B pancreatic cell
# Running: #99/#115 | Skin.basal cell of epidermis
# Running: #100/#115 | Skin.epidermal cell
# Running: #101/#115 | Skin.keratinocyte stem cell
# Running: #102/#115 | Skin.leukocyte
# Running: #103/#115 | Skin.stem cell of epidermis
# Running: #104/#115 | Spleen.B cell
# Running: #105/#115 | Spleen.T cell
# Running: #106/#115 | Spleen.macrophage
# Running: #107/#115 | Thymus.DN1 thymic pro-T cell
# Running: #108/#115 | Thymus.immature T cell
# Running: #109/#115 | Thymus.leukocyte
# Running: #110/#115 | Tongue.basal cell of epidermis
# Running: #111/#115 | Tongue.keratinocyte
# Running: #112/#115 | Trachea.blood cell
# Running: #113/#115 | Trachea.endothelial cell
# Running: #114/#115 | Trachea.epithelial cell
# Running: #115/#115 | Trachea.mesenchymal cell
# Writing files...
