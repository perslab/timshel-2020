# %%
import os
import sys

import numpy as np
import pandas as pd

# %%
# lib_path = os.path.abspath(os.path.pardir) # same as os.path.abspath("..")
lib_path = "/projects/timshel/sc-genetics/sc-genetics/src/lib"
sys.path.insert(1, lib_path)
from sem_pre_calculation import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Constants

# %% [markdown]
# ### Read data

# %%
### Metadata
file_metadata = "/projects/timshel/sc-scheele_lab_adipose_fluidigm_c1/data-preadipocytes_developing/preadipocyte_developing_1808.metadata.csv"
df_metadata = pd.read_csv(file_metadata, index_col=False)
df_metadata.head()
# Out:
#               cell_id branch_low_res      branch_high_res  nGene   nUMI  \
# 0  AAACCTGAGTCCTCCT-1   preadipocyte  preadipocyte_top100   4614  23660
# 1  AAACCTGCACAGGTTT-1   preadipocyte  preadipocyte_top100   3584  15599
# 2  AAACGGGAGGCTCTTA-1   preadipocyte   preadipocyte_top40   2979  13379
# 3  AAAGATGAGCTGGAAC-1   preadipocyte   preadipocyte_top90   3051  11689
# 4  AAAGCAACACTTACGA-1   preadipocyte  preadipocyte_top100   4084  18077
#
#       orig.ident timepoint  time_combined  percent.mito  res.0.5  \
# 0  SeuratProject        T1              1      0.026627        7
# 1  SeuratProject        T1              1      0.023078        7
# 2  SeuratProject        T1              1      0.042679        2
# 3  SeuratProject        T1              1      0.023783        7
# 4  SeuratProject        T1              1      0.028047        7
#
#         ...         Pseudotime   pc2.groups       pc1  pc2_supra_peri  \
# 0       ...           1.073875       middle -6.187852           other
# 1       ...           1.370154       middle -7.702770           other
# 2       ...          11.151146       middle -3.819590           other
# 3       ...           2.181324       middle -7.007155           other
# 4       ...           0.977370  top_10%_pc2 -7.175428           other
#
#    pc2_subq_visce       pc2       pc3       pc4        pc5 State.old.labels
# 0           other  3.331293 -3.359013 -1.964445  11.317299     preadipocyte
# 1           other  3.330828 -2.502859 -1.644394   9.496364     preadipocyte
# 2           other  1.676458 -1.378066 -2.576129  -1.121668     preadipocyte
# 3           other  1.384685 -0.724455 -3.301535   7.278057     preadipocyte
# 4           other  3.984249 -1.570916 -0.757836  12.493582     preadipocyte
#
# [5 rows x 61 columns]

# %%
### Data
file_data = "/projects/timshel/sc-scheele_lab_adipose_fluidigm_c1/data-preadipocytes_developing/preadipocyte_developing_1808.umi.csv.gz"
df_data = pd.read_csv(file_data, index_col=False) # this takes XXX min for adipocytes! (Pandas is slow!)

# %%
df_data.set_index("gene", inplace=True) # set index
df_data.head()
# Out:
#                  AAACCTGAGTCCTCCT-1  AAACCTGCACAGGTTT-1  AAACGGGAGGCTCTTA-1  \
# gene
# ENSG00000238009                   0                   0                   0
# ENSG00000237683                   0                   0                   0
# ENSG00000228463                   2                   2                   0
# ENSG00000237094                   0                   0                   0
# ENSG00000230021                   0                   0                   0
#
#                  AAAGATGAGCTGGAAC-1  AAAGCAACACTTACGA-1  AAAGCAACATTACGAC-1  \
# gene
# ENSG00000238009                   0                   0                   0
# ENSG00000237683                   0                   0                   0
# ENSG00000228463                   0                   0                   0
# ENSG00000237094                   0                   0                   0
# ENSG00000230021                   0                   0                   0
#
#                  AAAGCAAGTCGCATAT-1  AAAGTAGCAAGGACTG-1  AAAGTAGGTCCTCTTG-1  \
# gene
# ENSG00000238009                   0                   0                   0
# ENSG00000237683                   0                   0                   0
# ENSG00000228463                   1                   3                   0
# ENSG00000237094                   0                   0                   0
# ENSG00000230021                   0                   0                   0
#
#                  AAAGTAGGTTCGTCTC-1         ...          TATGCCCGTAGAGCTG-5  \
# gene                                        ...
# ENSG00000238009                   0         ...                           0
# ENSG00000237683                   0         ...                           0
# ENSG00000228463                   3         ...                           0
# ENSG00000237094                   0         ...                           0
# ENSG00000230021                   0         ...                           0
#
#                  TATTACCTCTATCGCC-5  TCAACGACACCATCCT-5  TCACGAACACCTCGGA-5  \
# gene
# ENSG00000238009                   0                   0                   0
# ENSG00000237683                   0                   0                   0
# ENSG00000228463                   0                   0                   0
# ENSG00000237094                   0                   0                   0
# ENSG00000230021                   0                   0                   0
#
#                  TGAGCATGTTTGACTG-5  TGATTTCGTTCAGTAC-5  TGGCCAGCATAACCTG-5  \
# gene
# ENSG00000238009                   0                   0                   0
# ENSG00000237683                   0                   0                   0
# ENSG00000228463                   0                   0                   0
# ENSG00000237094                   0                   0                   0
# ENSG00000230021                   0                   0                   0
#
#                  TGGCTGGGTAAGTGTA-5  TGTATTCGTAGCACGA-5  TTCGGTCAGTACGATA-5
# gene
# ENSG00000238009                   0                   0                   0
# ENSG00000237683                   0                   0                   0
# ENSG00000228463                   0                   0                   1
# ENSG00000237094                   0                   0                   0
# ENSG00000230021                   0                   0                   0
#
# [5 rows x 23428 columns]

# %%
### [*IMPORTANT*] Check that all metadata cell_ids are identical to data columnnames. 
### We need to ensure this before we can use the metadata cell-types as annotations.
np.all(df_data.columns.values == df_metadata["cell_id"].values) # ---> True
# Out:
# True

# %% [markdown]
# ### CTC log normalize

# %%
df_ctc_log = ctc_log_normalize(df_data)
# Out:
# Performning common transcript count (ctc) normalization and log-transformation on input data

# %% [markdown]
# ### Run pre-calc for multiple annotation levels

# %%
# <OUTPREFIX>:<ANNOTATION_LVL_COLUMN_NAME>
dict_run = {"preadipocyte_developing_1808_branch":"branch_low_res",
            "preadipocyte_developing_1808_branch_pc2_quantile":"branch_high_res"}

# %%
for out_prefix in dict_run:
    annotations = df_metadata[dict_run[out_prefix]].values # get annotations
    print(annotations[:5])
    df_anova = calculate_anova_sporadically_expressed_genes(df_ctc_log, annotations, out_prefix)
    df_anova.to_csv("{}.pre_calc.sporadically_expressed_genes.anova.csv.gz".format(out_prefix), compression="gzip")
    (df_frac, df_mu, df_var, df_n) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=False)
    (df_frac_null, df_mu_null, df_var_null, df_n_null) = calculate_per_anno_summary_stats(df_ctc_log, annotations, out_prefix, permute_annotations=True)
# Out:
# ['preadipocyte' 'preadipocyte' 'preadipocyte' 'preadipocyte'
#  'preadipocyte']
# Splitting data frame into annotation groups
# Splitting annotation #1/#3 into group
# Splitting annotation #2/#3 into group
# Splitting annotation #3/#3 into group
# Running ANOVA
# gene 0 out of 22979
# gene 100 out of 22979
# gene 200 out of 22979
# /tools/anaconda/3-4.4.0/envs/py3_anaconda3_PT180510/lib/python3.6/site-packages/scipy/stats/stats.py:2933: RuntimeWarning: invalid value encountered in double_scalars
#  'preadipocyte_top90' 'preadipocyte_top100']
# Splitting data frame into annotation groups
# Splitting annotation #1/#30 into group
# Splitting annotation #2/#30 into group
# Splitting annotation #3/#30 into group
# Splitting annotation #4/#30 into group
# Splitting annotation #5/#30 into group
# Splitting annotation #6/#30 into group
# Splitting annotation #7/#30 into group
# Splitting annotation #8/#30 into group
# Splitting annotation #9/#30 into group
# Splitting annotation #10/#30 into group
# Splitting annotation #11/#30 into group
# Splitting annotation #12/#30 into group
# Splitting annotation #13/#30 into group
# Splitting annotation #14/#30 into group
# Splitting annotation #15/#30 into group
# Splitting annotation #16/#30 into group
# Splitting annotation #17/#30 into group
# Splitting annotation #18/#30 into group
# Splitting annotation #19/#30 into group
# Splitting annotation #20/#30 into group
# Splitting annotation #21/#30 into group
# Splitting annotation #22/#30 into group
# Splitting annotation #23/#30 into group
# Splitting annotation #24/#30 into group
# Splitting annotation #25/#30 into group
# Splitting annotation #26/#30 into group
# Splitting annotation #27/#30 into group
# Splitting annotation #28/#30 into group
# Splitting annotation #29/#30 into group
# Splitting annotation #30/#30 into group
# Running ANOVA
# gene 0 out of 22979
# gene 100 out of 22979
# gene 200 out of 22979
# gene 300 out of 22979
# gene 400 out of 22979
# gene 500 out of 22979
# gene 600 out of 22979
# gene 700 out of 22979
# gene 800 out of 22979
# gene 900 out of 22979
# gene 1000 out of 22979
# gene 1100 out of 22979
# gene 1200 out of 22979
# gene 1300 out of 22979
# gene 1400 out of 22979
# gene 1500 out of 22979
# gene 1600 out of 22979
# gene 1700 out of 22979
# gene 1800 out of 22979
# gene 1900 out of 22979
# gene 2000 out of 22979
# gene 2100 out of 22979
# gene 2200 out of 22979
# gene 2300 out of 22979
# gene 2400 out of 22979
# gene 2500 out of 22979
# gene 2600 out of 22979
# gene 2700 out of 22979
# gene 2800 out of 22979
# gene 2900 out of 22979
# gene 3000 out of 22979
# gene 3100 out of 22979
# gene 3200 out of 22979
# gene 3300 out of 22979
# gene 3400 out of 22979
# gene 3500 out of 22979
# gene 3600 out of 22979
# gene 3700 out of 22979
# gene 3800 out of 22979
# gene 3900 out of 22979
# gene 4000 out of 22979
# gene 4100 out of 22979
# gene 4200 out of 22979
# gene 4300 out of 22979
# gene 4400 out of 22979
# gene 4500 out of 22979
# gene 4600 out of 22979
# gene 4700 out of 22979
# gene 4800 out of 22979
# gene 4900 out of 22979
# gene 5000 out of 22979
# gene 5100 out of 22979
# gene 5200 out of 22979
# gene 5300 out of 22979
# gene 5400 out of 22979
# gene 5500 out of 22979
# gene 5600 out of 22979
# gene 5700 out of 22979
# gene 5800 out of 22979
# gene 5900 out of 22979
# gene 6000 out of 22979
# gene 6100 out of 22979
# gene 6200 out of 22979
# gene 6300 out of 22979
# gene 6400 out of 22979
# gene 6500 out of 22979
# gene 6600 out of 22979
# gene 6700 out of 22979
# gene 6800 out of 22979
# gene 6900 out of 22979
# gene 7000 out of 22979
# gene 7100 out of 22979
# gene 7200 out of 22979
# gene 7300 out of 22979
# gene 7400 out of 22979
# gene 7500 out of 22979
# gene 7600 out of 22979
# gene 7700 out of 22979
# gene 7800 out of 22979
# gene 7900 out of 22979
# gene 20200 out of 22979
# gene 20300 out of 22979
# gene 20400 out of 22979
# gene 20500 out of 22979
# gene 20600 out of 22979
# gene 20700 out of 22979
# gene 20800 out of 22979
# gene 20900 out of 22979
# gene 21000 out of 22979
# gene 21100 out of 22979
# gene 21200 out of 22979
# gene 21300 out of 22979
# gene 21400 out of 22979
# gene 21500 out of 22979
# gene 21600 out of 22979
# gene 21700 out of 22979
# gene 21800 out of 22979
# gene 21900 out of 22979
# gene 22000 out of 22979
# gene 22100 out of 22979
# gene 22200 out of 22979
# gene 22300 out of 22979
# gene 22400 out of 22979
# gene 22500 out of 22979
# gene 22600 out of 22979
# gene 22700 out of 22979
# gene 22800 out of 22979
# gene 22900 out of 22979
# Number of genes sporadically expressed (pvalue > 0.00001, Skene cut-off): 11252
# Running: #1/#30 | ECM_top10
# Running: #2/#30 | ECM_top100
# Running: #3/#30 | ECM_top20
# Running: #4/#30 | ECM_top30
# Running: #5/#30 | ECM_top40
# Running: #6/#30 | ECM_top50
# Running: #7/#30 | ECM_top60
# Running: #8/#30 | ECM_top70
# Running: #9/#30 | ECM_top80
# Running: #10/#30 | ECM_top90
# Running: #11/#30 | oxidative_top10
# Running: #12/#30 | oxidative_top100
# Running: #13/#30 | oxidative_top20
# Running: #14/#30 | oxidative_top30
# Running: #15/#30 | oxidative_top40
# Running: #16/#30 | oxidative_top50
# Running: #17/#30 | oxidative_top60
# Running: #18/#30 | oxidative_top70
# Running: #19/#30 | oxidative_top80
# Running: #20/#30 | oxidative_top90
# Running: #21/#30 | preadipocyte_top10
# Running: #22/#30 | preadipocyte_top100
# Running: #23/#30 | preadipocyte_top20
# Running: #24/#30 | preadipocyte_top30
# Running: #25/#30 | preadipocyte_top40
# Running: #26/#30 | preadipocyte_top50
# Running: #27/#30 | preadipocyte_top60
# Running: #28/#30 | preadipocyte_top70
# Running: #29/#30 | preadipocyte_top80
# Running: #30/#30 | preadipocyte_top90
# Writing files...
# Doing null computation. Permuting labels with seed(1).
# Running: #1/#30 | ECM_top10
# Running: #2/#30 | ECM_top100
# Running: #3/#30 | ECM_top20
# Running: #4/#30 | ECM_top30
# Running: #5/#30 | ECM_top40
# Running: #6/#30 | ECM_top50
# Running: #7/#30 | ECM_top60
# Running: #8/#30 | ECM_top70
# Running: #9/#30 | ECM_top80
# Running: #10/#30 | ECM_top90
# Running: #11/#30 | oxidative_top10
# Running: #12/#30 | oxidative_top100
# Running: #13/#30 | oxidative_top20
# Running: #14/#30 | oxidative_top30
# Running: #15/#30 | oxidative_top40
# Running: #16/#30 | oxidative_top50
# Running: #17/#30 | oxidative_top60
# Running: #18/#30 | oxidative_top70
# Running: #19/#30 | oxidative_top80
# Running: #20/#30 | oxidative_top90
# Running: #21/#30 | preadipocyte_top10
# Running: #22/#30 | preadipocyte_top100
# Running: #23/#30 | preadipocyte_top20
# Running: #24/#30 | preadipocyte_top30
# Running: #25/#30 | preadipocyte_top40
# Running: #26/#30 | preadipocyte_top50
# Running: #27/#30 | preadipocyte_top60
# Running: #28/#30 | preadipocyte_top70
# Running: #29/#30 | preadipocyte_top80
# Running: #30/#30 | preadipocyte_top90
# Writing files...
